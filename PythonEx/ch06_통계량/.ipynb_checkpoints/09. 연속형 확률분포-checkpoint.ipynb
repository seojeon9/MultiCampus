# %% [markdown]
# # 대표적인 연속형 확률분포
#
# - 연속형 확률분포
#
#
#     - 정규분포(normal distribution)
#         - 대표본 모집단의 합, 평균 추론 시 활용
#     - t-분포
#         - 소표본 모집단 평균 추론 시 활용
#         - 선형모형 회귀계수 추론(종속변수 정규분포 가정)시 활용
#     - 카이제곱(χ2)분포
#         - 모집단 분산 추론 시(데이터 정규분포 가정) 활용
#         - 카이제곱 검정 시 활용
#     - F-분포
#         - 두 모집단 분산 차이 비교 시 활용(데이터 정규분포 가정)
#         - 분산분석 시 활용
#         - (설명하는 변동/설명하지 못하는 변동)이 F분포를 따름

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats, integrate
from scipy.optimize import minimize_scalar

# %precision 3
# %matplotlib inline

# %%
#한글문제 발생
#matplotlib의 기본폰트에서 한글지원 폰트가 없음
#패키지의 폰트를 추가하고 사용

import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')

# %%
linestyles = ['-', '--', ':']

def E(X, g=lambda x: x):
    x_range, f = X
    def integrand(x):
        return g(x) * f(x)
    return integrate.quad(integrand, -np.inf, np.inf)[0]

def V(X, g=lambda x: x):
    x_range, f = X
    mean = E(X, g)
    def integrand(x):
        return (g(x) - mean) ** 2 * f(x)
    return integrate.quad(integrand, -np.inf, np.inf)[0]

def check_prob(X):
    x_range, f = X
    f_min = minimize_scalar(f).fun
    assert f_min >= 0, 'density function is minus value'
    prob_sum = np.round(integrate.quad(f, -np.inf, np.inf)[0], 6)
    assert prob_sum == 1, f'sum of probability is {prob_sum}'
    print(f'expected vaue {E(X):.3f}')
    print(f'variance {V(X):.3f}')
    
def plot_prob(X, x_min, x_max):
    x_range, f = X
    def F(x):
        return integrate.quad(f, -np.inf, x)[0]

    xs = np.linspace(x_min, x_max, 100)

    fig = plt.figure(figsize=(10, 6))
    ax = fig.add_subplot(111)
    ax.plot(xs, [f(x) for x in xs],
            label='f(x)', color='gray')
    ax.plot(xs, [F(x) for x in xs],
            label='F(x)', ls='--', color='gray')

    ax.legend()
    plt.show()

# %% [markdown]
# ## 정규분포
#
# - 가장 대표적인 분포
# - 가우지안(Gaussian) 분포라고도 불리움
# - 연속형 확률변수에 대한 분포
# - 평균(μ)과 표준편차(σ)로 모양이 결정
# - 좌우대칭, 종모양
# - 중앙 한 점이 뾰족
# - 평균 = 중앙값 = 최빈값
# - 자연계, 사회현상에 많이 나타남
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 정규분포의 확률밀도함수 f(x)  ![image.png](attachment:image.png)
# - 연속확률변수
#
# ![image-3.png](attachment:image-3.png)

# %%
# mu : 평균, sigma : 표준편차
def N(mu, sigma) :
    x_range = [-np.inf, np.inf]
    def f(x) :
        return 1 / np.sqrt(2 * np.pi * sigma**2) *\
                    np.exp(-(x-mu)**2 / (2 * sigma**2))
    return x_range, f

# %%
mu, sigma = 2, 0.5
X = N(mu,sigma)

# %%
# 분산은 표준편차 0.5의 제곱
check_prob(X)
# Out:
# expected vaue 2.000
# variance 0.250

# %%
# X는 평균이 2 표준편차가 0.5일 정규분포를 따르는 확률변수
plot_prob(X,0,4)

# %% [markdown]
# - 남자 고등학생 키의 평균이 170cm 이고 표준편차가 5cm라면, 우연히 만난 남자 고등학생의 키는 N(170,5)를 따른다고 할 수 있다.
#
#
#
# - 남자 고등학생의 키 ~ N(170, 5)
#
#
# - 이 사실을 바탕으로 우연히 만난 남자 고등학생의 키가 165cm 이상 175cm 이하일 확률은

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def N(mu,sigma) :
    x_range = [165,175]
    def f(x) :
        return 1 / np.sqrt(2 * np.pi * sigma**2) *\
                    np.exp(-(x-mu)**2 / (2 * sigma**2))
    return x_range, f

# %%
mu, sigma = 170, 5
X = N(mu, sigma)

# %%
x_range, f = X
np.round(integrate.quad(f, x_range[0],x_range[1])[0],6) # 구간을 작게 나누고 수치접근
# Out:
# 0.682689

# %% [markdown]
# - 모의고사 평균 점수가 70점이고 표준편차가 8점이라면, 우연히 만난 학생의 점수가 N(70, 8^2)를 따른다고 할 수 있다.
#
#
# - 모의고사 점수 ~ N(70, 8^2)
#
#
# - 이 사실을 바탕으로 우연히 만난 학생의 점수가 54점 이상 86점 이하일 확률은?

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def N(mu,sigma) :
    x_range = [54,86]
    def f(x) :
        return 1 / np.sqrt(2 * np.pi * sigma**2) *\
                    np.exp(-(x-mu)**2 / (2 * sigma**2))
    return x_range, f

# %%
mu, sigma = 70, 8
X = N(mu,sigma)

x_range, f = X
np.round(integrate.quad(f, x_range[0],x_range[1])[0],6)
# Out:
# 0.9545

# %% [markdown]
# ### scipy.state 사용해서 확인

# %%
# norm()
# 기댓값이 2이고 표준편차가 0.5인 정규분포를 따르는 확률변수 생성
rv = stats.norm(2,0.5)

# %%
# 확률변수의 평균과 분산
# mean(), var()
rv.mean(), rv.var()
# Out:
# (2.0, 0.25)

# %%
# pdf : 연속 확률변수의 확률 밀도 함수
rv.pdf(2)
# 연속 확률변수이므로 발생값이 2일 확률이 계산되지 않는다.
# 면적계산이어야 하므로 pdf를 사용하지 않고 누적밀도함수인 cdf를 사용해서 계산해야함
# Out:
# 0.7978845608028654

# %%
xx = np.linspace(-2, 6, 100)
xx
# Out:
# array([-2.   , -1.919, -1.838, -1.758, -1.677, -1.596, -1.515, -1.434,
#        -1.354, -1.273, -1.192, -1.111, -1.03 , -0.949, -0.869, -0.788,
#        -0.707, -0.626, -0.545, -0.465, -0.384, -0.303, -0.222, -0.141,
#        -0.061,  0.02 ,  0.101,  0.182,  0.263,  0.343,  0.424,  0.505,
#         0.586,  0.667,  0.747,  0.828,  0.909,  0.99 ,  1.071,  1.152,
#         1.232,  1.313,  1.394,  1.475,  1.556,  1.636,  1.717,  1.798,
#         1.879,  1.96 ,  2.04 ,  2.121,  2.202,  2.283,  2.364,  2.444,
#         2.525,  2.606,  2.687,  2.768,  2.848,  2.929,  3.01 ,  3.091,
#         3.172,  3.253,  3.333,  3.414,  3.495,  3.576,  3.657,  3.737,
#         3.818,  3.899,  3.98 ,  4.061,  4.141,  4.222,  4.303,  4.384,
#         4.465,  4.545,  4.626,  4.707,  4.788,  4.869,  4.949,  5.03 ,
#         5.111,  5.192,  5.273,  5.354,  5.434,  5.515,  5.596,  5.677,
#         5.758,  5.838,  5.919,  6.   ])

# %%
pdf = rv.pdf(xx)
pdf
# Out:
# array([1.010e-14, 3.634e-14, 1.273e-13, 4.345e-13, 1.445e-12, 4.680e-12,
#        1.477e-11, 4.541e-11, 1.360e-10, 3.969e-10, 1.128e-09, 3.125e-09,
#        8.432e-09, 2.216e-08, 5.676e-08, 1.416e-07, 3.441e-07, 8.148e-07,
#        1.880e-06, 4.224e-06, 9.247e-06, 1.972e-05, 4.098e-05, 8.296e-05,
#        1.636e-04, 3.144e-04, 5.884e-04, 1.073e-03, 1.906e-03, 3.299e-03,
#        5.562e-03, 9.136e-03, 1.462e-02, 2.279e-02, 3.462e-02, 5.122e-02,
#        7.383e-02, 1.037e-01, 1.419e-01, 1.891e-01, 2.455e-01, 3.106e-01,
#        3.827e-01, 4.595e-01, 5.375e-01, 6.125e-01, 6.799e-01, 7.353e-01,
#        7.748e-01, 7.953e-01, 7.953e-01, 7.748e-01, 7.353e-01, 6.799e-01,
#        6.125e-01, 5.375e-01, 4.595e-01, 3.827e-01, 3.106e-01, 2.455e-01,
#        1.891e-01, 1.419e-01, 1.037e-01, 7.383e-02, 5.122e-02, 3.462e-02,
#        2.279e-02, 1.462e-02, 9.136e-03, 5.562e-03, 3.299e-03, 1.906e-03,
#        1.073e-03, 5.884e-04, 3.144e-04, 1.636e-04, 8.296e-05, 4.098e-05,
# ...

# %%
pdf.mean()
pdf.var()
# Out:
# 0.05450439846403486

# %%
xx = np.linspace(-2, 6, 100)
pdf = rv.pdf(xx)
plt.plot(xx, pdf)
plt.title("확률밀도함수 ")
plt.xlabel("$x$")
plt.ylabel("$p(x)$")
plt.show()

# %% [markdown]
# - 확률 변수의 확률 분포 값 : cdf 로 계산
# - 분포 함수 : P(X <= x) 를 계산하는 함수
#
# - cdf(x)
#
# ![image.png](attachment:image.png)

# %%
# X가 1.7보다 작은 값이 되는 확률
rv.cdf(1.7)
# Out:
# 0.27425311775007355

# %%
rv.cdf(np.inf)
# Out:
# 1.0

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
#
#
#     - 𝑃(𝑋≥x) = 𝛼를 만족하는 x
#
#
# ![image.png](attachment:image.png)
#
#
# ![image-4.png](attachment:image-4.png)

# %%
# 상위 30% 점
rv.isf(0.3)
# Out:
# 2.2622002563540207

# %%
# 상위 70% 점(하위 30% 점)
rv.isf(0.7)
# Out:
# 1.7377997436459798

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
#
# ![image-3.png](attachment:image-3.png)
#
#
#
# - 구간 [a, b]는 100𝛼"%" 구간

# %%
# 90% 구간
rv.interval(0.9)
# Out:
# (1.1775731865242636, 2.822426813475736)

# %%
# 왼쪽과 오른쪽  끝에 5% 씩 남기 때문에 아래와 같이 구할 수도 잇다
rv.isf(0.95),rv.isf(0.05)
# Out:
# (1.1775731865242638, 2.8224268134757367)

# %%
# 평균이 2이고 표준편차가 0.5인 정규분포를 따르는 확률변수 rv에 의해
# 표현되는 90%구간의 확률을 구하시오
# 90%구간의 경계점
rv.interval(0.9)
rv.cdf(2.822) - rv.cdf(1.178)
# Out:
# 0.8998237976236567

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)

xs = np.linspace(-5, 5, 100)
params = [(0, 1), (0, 2), (1, 1)]
for param, ls in zip(params, linestyles):
    mu, sigma = param
    rv = stats.norm(mu, sigma)
    ax.plot(xs, rv.pdf(xs),
            label=f'N({mu}, {sigma**2})', ls=ls, color='gray')
ax.legend()

plt.show()

# %% [markdown]
# ###  남자 고등학생의 키 ~ N(170, 5^2)

# %%
rv = stats.norm(170,5)

# %%
 # 정규분포를 따르는 확률변수 rv

xx = np.linspace(150,190, 100)
pdf = rv.pdf(xx)
plt.plot(xx, pdf)
plt.title("확률밀도함수 ")
plt.xlabel("$x$")
plt.ylabel("$p(x)$")
plt.show()

# %%
pdf
# Out:
# array([2.677e-05, 3.686e-05, 5.043e-05, 6.854e-05, 9.256e-05, 1.242e-04,
#        1.655e-04, 2.192e-04, 2.883e-04, 3.768e-04, 4.893e-04, 6.312e-04,
#        8.090e-04, 1.030e-03, 1.303e-03, 1.638e-03, 2.045e-03, 2.536e-03,
#        3.126e-03, 3.827e-03, 4.655e-03, 5.626e-03, 6.755e-03, 8.057e-03,
#        9.548e-03, 1.124e-02, 1.315e-02, 1.528e-02, 1.764e-02, 2.023e-02,
#        2.305e-02, 2.610e-02, 2.936e-02, 3.280e-02, 3.641e-02, 4.016e-02,
#        4.401e-02, 4.791e-02, 5.181e-02, 5.567e-02, 5.943e-02, 6.302e-02,
#        6.640e-02, 6.951e-02, 7.228e-02, 7.468e-02, 7.666e-02, 7.818e-02,
#        7.920e-02, 7.972e-02, 7.972e-02, 7.920e-02, 7.818e-02, 7.666e-02,
#        7.468e-02, 7.228e-02, 6.951e-02, 6.640e-02, 6.302e-02, 5.943e-02,
#        5.567e-02, 5.181e-02, 4.791e-02, 4.401e-02, 4.016e-02, 3.641e-02,
#        3.280e-02, 2.936e-02, 2.610e-02, 2.305e-02, 2.023e-02, 1.764e-02,
#        1.528e-02, 1.315e-02, 1.124e-02, 9.548e-03, 8.057e-03, 6.755e-03,
# ...

# %%
# 우연히 만난 남자 고등학생의 키가 165이상 175이하일 확률은?
rv.cdf(175)-rv.cdf(165)
# Out:
# 0.6826894921370859

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### A농장에서 무게가 203.81g ~ 302.9g 사이에 해당하는 사과가 선택될 확률
# - 단 A농장의 사과는 평균무게 300g 표준편차 50g임

# %%
# 평균이 300g 이고 표준편차가 50g인 정규분포 객체 변수 생성
rv = stats.norm(300,50)

# %%
# cdf 메서드 사용 확률 계산
# 무게가 203.81g일때까지의 확률
rv.cdf(203.81)
# Out:
# 0.027189828720993854

# %%
# 무게가 302.9g 이하일 확률
rv.cdf(302.9)
# Out:
# 0.5231256857358382

# %%
rv.cdf(302.9) - rv.cdf(203.81)
# Out:
# 0.49593585701484433

# %% [markdown]
# ## 카이제곱분포
#
# - Z는 정규분포, 자유도는 정규분포의 갯수(n)
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %%
n = 10
rv = stats.norm(0,1)
sample_size = int(1e6)

# %%
# norm.rvs(size, random_state=seed값 고정) 
# rvs : 난수 생성해주는 함수
# sample 추출(정규분포를 따르는 난수 생성)
Zs_sample = rv.rvs((10,5))
Zs_sample
# Out:
# array([[-0.12 , -0.664,  0.854, -1.575,  0.108],
#        [-0.447,  1.306,  0.747, -0.614,  1.524],
#        [ 0.824, -0.506,  0.226, -0.449, -1.011],
#        [ 1.903,  0.59 , -0.439, -0.817,  0.816],
#        [-2.097, -0.809, -0.105, -0.662, -0.211],
#        [ 0.673,  1.553,  0.016, -0.563,  1.09 ],
#        [ 1.197,  0.282, -0.328,  1.643,  0.645],
#        [-0.693, -0.62 , -1.542,  1.187, -0.512],
#        [-3.07 , -0.816,  0.079, -0.171, -0.708],
#        [-1.237,  0.033,  1.415,  0.573, -0.932]])

# %%
# 표준정규분포로부터 10*100만 사이즈로 무작위 추출
Zs_sample = rv.rvs((n,sample_size))
# Zs_sample

chi2_sample = np.sum(Zs_sample**2,axis=0)

# %%
len(chi2_sample)
# Out:
# 1000000

# %% [markdown]
# ### 카이제곱 분포를 따르는 확률변수 생성 : stats.chi2(n)

# %%
n = 10
rv_true = stats.chi2(n)

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
xs = np.linspace(0, 30, 100)

# sample 데이터 이용 카이제곱분포 계산 데이터를 이용한 히스토그램
ax.hist(chi2_sample, bins=100, density=True,
      alpha=0.5, label='chi2_sample')


# 카이제곱 밀도 함수를 사용한 그래프
ax.plot(xs,rv_true.pdf(xs), label=f'chi2({n})', color='gray')

ax.legend()
ax.set_xlim(0, 30)
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)

# n(자유도)값을변경해가면서 그래프 생성
xs = np.linspace(0, 20, 500)
for n, ls in zip([3, 5, 10], linestyles):
    rv = stats.chi2(n)
    ax.plot(xs, rv.pdf(xs),
            label=f'chi2({n})', ls=ls, color='gray')
    
ax.legend()
plt.show()

# %% [markdown]
# - 카이제곱분포는 기본적으로 좌측에 치우친 분포인데, 자유도가 커질수록 대칭의 분포로 접근한다.
#     - n이 커지면 분산도가 높아져서 꼭짓점이 낮아짐. 즉 데이터의 산포가 커진다

# %%
# 자유도가 5 일때
rv = stats.chi2(5)
# 상위 5프로 점
print(rv.isf(0.05))
# 상위 95프로 점
print(rv.isf(0.95))
# Out:
# 11.070497693516355
# 1.1454762260617697

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## t분포 - 정규분포에서 모평균의 구간추정 등에 사용되는 확률분포
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 정규분포와 카이분포 사이의 관계
n = 10
rv1 = stats.norm() # 표준 정규분포 확률변수 생성
rv2 = stats.chi2(n) # 자유도가 10일 카이제곱분포 확률변수 생성

sample_size = int(1e6)
z_sample = rv1.rvs(sample_size)
chi2_sample = rv2.rvs(sample_size)

t_sample = z_sample / np.sqrt(chi2_sample/n)

# %%
z_sample
chi2_sample
t_sample
# Out:
# array([-0.103,  1.728, -1.129, ...,  1.67 ,  0.514,  0.762])

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)

# t 확률 변수생성 

rv = stats.t(n)
xs = np.linspace(-3, 3, 100)
# sample로 직접 계산한 t 결과값의 히스토 그램
ax.hist(t_sample, bins=100, range=(-3,3),
       density=True, alpha=0.5, label='t_sample')

# 확률 밀도 함수 이용해 x의 대응 확률함수 값  계산
ax.plot(xs, rv.pdf(xs),label=f't({n})', color='gray')

ax.legend()
ax.set_xlim(-3, 3)
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)

xs = np.linspace(-3, 3, 100)
for n, ls in zip([3, 5, 10], linestyles):
    rv = stats.t(n)
    ax.plot(xs, rv.pdf(xs),
            label=f't({n})', ls=ls, color='gray')
rv = stats.norm()
ax.plot(xs, rv.pdf(xs), label='N(0, 1)')
    
ax.legend()
plt.show()
# 자유도가 커질수록 정규분포에 가까워진다. (꼭짓점이 높아지고 양쪽 끝이 0에 가까워 진다.)

# %%
rv = stats.t(5)
rv.isf(0.05)
# Out:
# 2.0150483726691575

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## F분포-분산분석 등에서 사용되는 확률분포
#
# ![image-2.png](attachment:image-2.png)
#
# - 서로 독립인두 확률변수 Y1과 Y2가 각각 자유도 n1, n2인카이제곱 분포를 따를때 새로운 확률변수
#     - F = (Y1/n1)/(Y2/n2) 는 F-분포를따른다

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n1 = 5
n2 = 10
rv1 = stats.chi2(n1)
rv2 = stats.chi2(n2)

sample_size = int(1e6)
sample1 = rv1.rvs(sample_size)
sample2 = rv2.rvs(sample_size)

f_sample = (sample1/n1) / (sample2/n2)
f_sample
# Out:
# array([1.527, 1.376, 1.52 , ..., 1.675, 1.633, 2.243])

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)

rv = stats.f(n1, n2)
xs = np.linspace(0, 6, 200)[1:]
ax.hist(f_sample,bins=100,range=(0,6),
       density=True, alpha=0.5, label='f_sample')
ax.plot(xs, rv.pdf(xs),label=f'F({n1}, {n2})', color='gray')

ax.legend()
ax.set_xlim(0, 6)
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)

xs = np.linspace(0, 6, 200)[1:]
for n1, ls in zip([3, 5, 10], linestyles):
    rv = stats.f(n1, 10)
    ax.plot(xs, rv.pdf(xs),
            label=f'F({n1}, 10)', ls=ls, color='gray')
    
ax.legend()
plt.show()
