# %%
import pandas as pd
import numpy as np
import folium
# 경고 메시지 무시 설정
import warnings
warnings.filterwarnings(action='ignore')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.11) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
res_table = pd.read_csv('./datas/서울시 착한가격음식점(map 매핑버전).csv',encoding='CP949', index_col=0)
res_table.head(10)
# Out:
#      업소아이디            업소명              메뉴     가격         위도          경도  행정구  \
# 140   8508          장독묵은지            감치찌개   6000  37.488688  127.066845  강남구
# 183   8524          다복콩비지  오리로스(400g 반마리)  23000  37.477099  127.049212  강남구
# 234   8507          우리생고기             청국장   6000  37.488898  127.068580  강남구
# 258   8518      노숙자아구샤브샤브         해물된장비빔밥   6000  37.478087  127.048213  강남구
# 262   8515          누이야식당             순두부   6000  37.472653  127.051397  강남구
# 276   8516        동대문곱창전문           오늘의메뉴   5000  37.474004  127.049819  강남구
# 287   8514         바지락칼국수            된장찌개   6000  37.478896  127.045639  강남구
# 299   9002            처갓집             북어국   6000  37.472370  127.051706  강남구
# 327   9005          수타손짜장    짜장+짬뽕+탕수육set  10000  37.492658  127.075585  강남구
# 339   8512  숙아채 콩나물국밥(개포)           콩나물국밥   5000  37.477757  127.047833  강남구
#
#      행정동    별점       식당아이디
# 140  개포동  4.38    18419672
# 183  개포동     -           -
# 234  개포동  4.24    36004730
# 258  개포동     -           -
# 262  개포동  4.29    13358439
# 276  개포동     -  1867169591
# 287  개포동  4.58    20877928
# 299  개포동  4.26    37065452
# 327  개포동  4.42  1750362890
# 339  개포동     -           -

# %%
def input_gu_dong() :
    # 행정구 입력
    gu = res_table['행정구'].unique()
    while True :
        print(gu)
        input_gu = input('행정구를 입력하세요 : ')
        if input_gu in gu :
            break
        else :
            print("\n다시 확인 후 진행해주세요\n")
       
    # 행정동 입력
    dong_table = res_table[res_table['행정구']==input_gu]
    dong = dong_table['행정동'].unique()
    while True :
        print('\n',dong)
        input_dong = input('행정동를 입력하세요 : ')
        if input_dong in dong :
            break
        else :
            print("\n다시 확인 후 진행해주세요\n")
            
    return input_dong

# %%
def print_map(input_dong) :
    # 행정동 데이터 set
    target_table = res_table[res_table['행정동']==input_dong ]
    target_table.index = [i for i in range(len(target_table))]

    map = folium.Map(location=[target_table['위도'][0],target_table['경도'][0]],
                   zoom_start=13)

    for i in target_table.index :
        name = target_table['업소명'][i]
        star = target_table['별점'][i]
        menu = target_table['메뉴'][i]
        price = target_table['가격'][i]

        iframe = "이름 : " + name+ "<br> 별점 : "+ star + "<br> 대표메뉴 :" + menu + " [" + price + "]" 
        popup = folium.Popup(iframe, min_width=150, max_width=200)
        
        folium.Marker([target_table['위도'][i],target_table['경도'][i]], 
                      popup=popup, tooltip=name,
                      icon=folium.Icon(color='green')).add_to(map)

    return map

# %%
dong = input_gu_dong()
map = print_map(dong)
map
# Out:
# ['강남구' '강동구' '강북구' '강서구' '관악구' '광진구' '구로구' '금천구' '노원구' '도봉구' '동대문구' '동작구'
#  '마포구' '서대문구' '서초구' '성동구' '성북구' '송파구' '양천구' '영등포구' '용산구' '은평구' '종로구' '중구'
#  '중랑구']
# 행정구를 입력하세요 : 강남구
#
#  ['개포동' '논현동' '대치동' '도곡동' '삼성동' '수서동' '신사동' '역삼동' '율현동' '일원동' '청담동']
# 행정동를 입력하세요 : 개포동
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb8352e7478fbdaa284ee8f1a7690f5e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb8352e7478fbdaa284ee8f1a7690f5e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_fb8352e7478fbdaa284ee8f1a7690f5e = L.map(
#                 &quot;map_fb8352e7478fbdaa284ee8f1a7690f5e&quot;,
#                 {
#                     center: [37.48868793, 127.0668453],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd1a6d7bc6edcb27240b06c2daa4f39e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fb8352e7478fbdaa284ee8f1a7690f5e);
#
#
#             var marker_ccdf35300e41da816d5b764b4bbe631c = L.marker(
#                 [37.48868793, 127.0668453],
#                 {}
#             ).addTo(map_fb8352e7478fbdaa284ee8f1a7690f5e);
#
#
#             var icon_5fc020589b787313c28323ae2474b5c6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ccdf35300e41da816d5b764b4bbe631c.setIcon(icon_5fc020589b787313c28323ae2474b5c6);
#
#
#         var popup_61229d4dfcab1e4e64533a53e5156ee4 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 150});
#
#
#             var html_5ab9902deb6a54e178b773a265313be0 = $(`&lt;div id=&quot;html_5ab9902deb6a54e178b773a265313be0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;이름 : 장독묵은지&lt;br&gt; 별점 : 4.38&lt;br&gt; 대표메뉴 :감치찌개 [6000]&lt;/div&gt;`)[0];
#             popup_61229d4dfcab1e4e64533a53e5156ee4.setContent(html_5ab9902deb6a54e178b773a265313be0);
#
#
#         marker_ccdf35300e41da816d5b764b4bbe631c.bindPopup(popup_61229d4dfcab1e4e64533a53e5156ee4)
#         ;
#
#
#
#
#             marker_ccdf35300e41da816d5b764b4bbe631c.bindTooltip(
#                 `&lt;div&gt;
#                      장독묵은지
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bc0682aa573a5d0efaba51ee4eb499c3 = L.marker(
#                 [37.47709916, 127.0492122],
#                 {}
#             ).addTo(map_fb8352e7478fbdaa284ee8f1a7690f5e);
#
#
#             var icon_a5e608ecaace49a67c83216dfd97aade = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bc0682aa573a5d0efaba51ee4eb499c3.setIcon(icon_a5e608ecaace49a67c83216dfd97aade);
#
#
#         var popup_2b4cf14c7df188b74cd9ae3615a4cec4 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 150});
#
#
#             var html_8cacec1ffb4d69b75bc730b47de03d93 = $(`&lt;div id=&quot;html_8cacec1ffb4d69b75bc730b47de03d93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;이름 : 다복콩비지&lt;br&gt; 별점 : -&lt;br&gt; 대표메뉴 :오리로스(400g 반마리) [23000]&lt;/div&gt;`)[0];
#             popup_2b4cf14c7df188b74cd9ae3615a4cec4.setContent(html_8cacec1ffb4d69b75bc730b47de03d93);
#
#
#         marker_bc0682aa573a5d0efaba51ee4eb499c3.bindPopup(popup_2b4cf14c7df188b74cd9ae3615a4cec4)
#         ;
#
#
#
#
#             marker_bc0682aa573a5d0efaba51ee4eb499c3.bindTooltip(
#                 `&lt;div&gt;
#                      다복콩비지
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f8de788b6ae244523e7660b092b768ea = L.marker(
#                 [37.48889849, 127.0685805],
#                 {}
#             ).addTo(map_fb8352e7478fbdaa284ee8f1a7690f5e);
#
#
#             var icon_4b5cbf9c17f7cce108fa96d9494106c4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f8de788b6ae244523e7660b092b768ea.setIcon(icon_4b5cbf9c17f7cce108fa96d9494106c4);
#
#
#         var popup_2d70fd98547bc04eaf35b2332701aca2 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 150});
#
#
#             var html_473cf216a08f2dda9dc0c1e7e775bd55 = $(`&lt;div id=&quot;html_473cf216a08f2dda9dc0c1e7e775bd55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;이름 : 우리생고기&lt;br&gt; 별점 : 4.24&lt;br&gt; 대표메뉴 :청국장 [6000]&lt;/div&gt;`)[0];
#             popup_2d70fd98547bc04eaf35b2332701aca2.setContent(html_473cf216a08f2dda9dc0c1e7e775bd55);
#
#
#         marker_f8de788b6ae244523e7660b092b768ea.bindPopup(popup_2d70fd98547bc04eaf35b233
