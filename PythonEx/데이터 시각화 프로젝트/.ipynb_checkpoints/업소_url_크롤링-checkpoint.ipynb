# %% [markdown]
# ### 착한가격업소 크롤링

# %%
# 패키지 임포트
import selenium
from selenium import webdriver
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
import time
from tqdm import tqdm_notebook

# %%
res_table = pd.read_csv("./datas/서울시 착한가격음식점(지역추가).csv", encoding='CP949',index_col=0)
res_table

# %%
search_res = []
for i in res_table.index :
    addr = []
    addr.append(res_table['행정구'][i])
    addr.append(res_table['행정동'][i])
    addr.append(res_table['업소명'][i])
    str = " ".join(addr)
    search_res.append(str)

# %%
search_res

# %%
res_table['검색명'] = search_res

# %%
base_url='https://map.naver.com/v5/?c=14127676.3957465,4523397.9832608,15,0,0,0,dh'

# %%
driver = webdriver.Chrome('./driver/chromedriver')
driver.get(base_url)
time.sleep(2)

# %%
url_list = []

# %%
for res in tqdm_notebook(res_table['검색명']) :
    try :
        search_xpath = '/html/body/app/layout/div[3]/div[2]/shrinkable-layout/div/app-base/search-input-box/div/div[1]/div/input'
        element = driver.find_element(By.XPATH, search_xpath)
        time.sleep(0.5)
        element.clear()
        element.send_keys(res)
        element.send_keys("\n")
        time.sleep(3)
        
        url = driver.current_url
        if(url.split('/').__contains__('place')) :
            u = url.split('/')[-1].split('?')[0]
            url_list.append(u)
        else :
            driver.switch_to.frame('searchIframe')
            time.sleep(1)
            
            target_xpath = '/html/body/div[3]/div/div/div[1]/ul/li[1]/div[2]/a[1]/div/div/span[1]'
            config = driver.find_elements(By.XPATH, target_xpath)
            if len(config) == 0 :
                target_xpath = '/html/body/div[3]/div/div/div[1]/ul/li[1]/div[1]/a[1]/div/div/span[1]'
            else :
                target_xpath = '/html/body/div[3]/div/div/div[1]/ul/li[1]/div[2]/a[1]/div/div/span[1]'
                
            element = driver.find_element(By.XPATH, target_xpath)
            element.click()
            time.sleep(2)

            url = driver.current_url
            u = url.split('/')[-1].split('?')[0]
            url_list.append(u)
            time.sleep(1)

            driver.switch_to.default_content()
            time.sleep(1)
                
    except :
        print('error',res)
        url_list.append('-')
        driver.switch_to.default_content()
        time.sleep(1)

# %%
driver.close()

# %%
res_table['업소URL'] = url_list

# %%
res_table.to_csv('./datas/서울시 착한가격음식점(업소URL추가).csv', encoding='CP949' )

# %% [markdown]
# ### 일반음식점 서대문구 크롤링

# %%
res_table = pd.read_csv("./datas/서대문구 표본.csv", encoding='CP949')
res_table
# Out:
#     상세영업상태명          전화번호   소재지면적  소재지우편번호  \
# 0        영업  02  302 1946   13.20   120816
# 1        영업  02  322 7300   59.64   120825
# 2        영업     203236665   84.12   120834
# 3        영업    02 3625222  179.83   120012
# 4        영업    02 3226988   34.51   120834
# ..      ...           ...     ...      ...
# 337      영업    02 7201544   67.16   120854
# 338      영업           NaN   62.00   120809
# 339      영업  02  936 7414   63.99   120834
# 340      영업           NaN   34.28   120847
# 341      영업   02  3950505   28.56   120100
#
#                                     지번주소                                도로명주소  \
# 0       서울특별시 서대문구 북가좌동 382-18번지 (지하1층)   서울특별시 서대문구 수색로10길 12-1 (북가좌동(지하1층))
# 1    서울특별시 서대문구 연희동 188-89번지 가동 지하1층 전체      서울특별시 서대문구 연희맛로 12 가동 지하1층 (연희동)
# 2             서울특별시 서대문구 창천동 72-29번지 1층            서울특별시 서대문구 연세로5다길 39 (창천동)
# 3                   서울특별시 서대문구 충정로2가 18        서울특별시 서대문구 충정로11길 8 지층 (충정로2가)
# 4         서울특별시 서대문구 창천동 72-22번지 (지상1층)                                   NaN
# ..                                   ...                                  ...
# 337               서울특별시 서대문구 홍제동 139-15        서울특별시 서대문구 홍제원길 4-3 지상1층 (홍제동)
# 338          서울특별시 서대문구 대현동 101-12번지 1층            서울특별시 서대문구 신촌역로 6 1층 (대현동)
# 339        서울특별시 서대문구 창천동 53-23 창서빌딩 1층     서울특별시 서대문구 연세로7길 46 창서빌딩 1층 (창천동)
# 340               서울특별시 서대문구 홍은동 277-157       서울특별시 서대문구 연희로 283 1층 3호 (홍은동)
# 341             서울특별시 서대문구 홍은동 48-64 1층      서울특별시 서대문구 세검정로1길 100-7 1층 (홍은동)
#
#      도로명우편번호       사업장명        최종수정일자 데이터갱신구분  데이터갱신일자    업태구분명      좌표정보(X)  \
# 0     3714.0      식도락식당  2.010020e+13       I  59:59.0       한식  191577.3162
# 1     3708.0        선굼터  2.018020e+13       I  59:59.0       한식  193680.3181
# 2     3787.0    아저씨네낙지찜  2.013060e+13       I  59:59.0       한식  194043.3271
# 3     3735.0         미향  2.021090e+13       U  40:00.0       한식  196912.7134
# 4        NaN     떳다껍데기2  2.004060e+13       I  59:59.0       한식  194058.4832
# ..       ...        ...           ...     ...      ...      ...          ...
# 337   3632.0        야미가  2.021080e+13       U  40:00.0  김밥(도시락)  195273.8158
# 338   3766.0     이대종합분식  2.018120e+13       U  40:00.0  김밥(도시락)  194904.0273
# 339   3787.0  배달돼지 소태식품  2.021020e+13       U  40:00.0  김밥(도시락)  194132.9327
# 340   3652.0    민셰프 도시락  2.022080e+13       U  08:00.0  김밥(도시락)  194272.5499
# 341   3611.0   청년김밥&떡볶이  2.021100e+13       I  22:46.0  김밥(도시락)  195208.9930
#
#          좌표정보(Y)    위생업태명
# 0    452607.3966       한식
# 1    451545.9917       한식
# 2    450504.7352       한식
# 3    451494.2447       한식
# 4    450476.2442       한식
# ..           ...      ...
# 337  453794.4153  김밥(도시락)
# 338  450560.3728  김밥(도시락)
# 339  450640.8130  김밥(도시락)
# 340  453343.4427      NaN
# 341  454707.6967  김밥(도시락)
#
# [342 rows x 15 columns]

# %%
res_table['지번주소'][0].split(' ')[1:3]
# Out:
# ['서대문구', '북가좌동']

# %%
search_res = []
addr = res_table['지번주소'][0].split(' ')[1:3]
addr.append(res_table['사업장명'][0])
s = " ".join(addr)
search_res.append(s)
search_res
# Out:
# ['서대문구 북가좌동 식도락식당']

# %%
search_res = []
for i in res_table.index :
    try :
        addr = res_table['지번주소'][i].split(' ')[1:3]
        addr.append(res_table['사업장명'][i])
        s = " ".join(addr)
        search_res.append(s)
    except :
        print(i)
        search_res.append('-')
search_res
# Out:
# ['서대문구 북가좌동 식도락식당',
#  '서대문구 연희동 선굼터',
#  '서대문구 창천동 아저씨네낙지찜',
#  '서대문구 충정로2가 미향',
#  '서대문구 창천동 떳다껍데기2',
#  '서대문구 홍은동 송마분식',
#  '서대문구 홍제동 포메인 홍제점',
#  '서대문구 홍은동 참숯돼지천국',
#  '서대문구 홍제동 윤이 불닭발',
#  '서대문구 충정로2가 복성각',
#  '서대문구 홍제동 토종 순대국',
#  '서대문구 연희동 가을',
#  '서대문구 창천동 복성 청요릿집 신촌점',
#  '서대문구 창천동 총각들의잔치 반찬하우스',
#  '서대문구 창천동 신촌아지트',
#  '서대문구 창천동 양푼이주막',
#  '서대문구 북가좌동 버텍스 상암점',
#  '서대문구 충정로3가 고릴라',
#  '서대문구 대현동 이 세계는 놀이터에요',
#  '서대문구 옥천동 더풍년',
#  '서대문구 충정로3가 한 우리',
#  '서대문구 충정로3가 진주식당',
#  '서대문구 영천동 도깨비 칼국수',
#  '서대문구 대현동 나주곰탕',
#  '서대문구 충정로2가 시골장터',
#  '서대문구 홍제동 우리집',
#  '서대문구 충정로2가 알리오 올리오 스파케티전문점',
#  '서대문구 연희동 연희식당',
#  '서대문구 홍은동 와글바글',
#  '서대문구 충정로3가 히비야',
#  '서대문구 대현동 파오',
#  '서대문구 홍제동 원조양평해장국',
#  '서대문구 홍은동 산천마루 누룽지백숙 삼계탕 간장게장',
#  '서대문구 홍은동 옥이네 왕돈가',
#  '서대문구 연희동 연희 화로',
#  '서대문구 홍제동 무학바지락칼국수',
#  '서대문구 홍은동 본도시락(홍은점)',
#  '서대문구 창천동 온달집',
#  '서대문구 연희동 육정성',
#  '서대문구 홍제동 토속보리밥',
#  '서대문구 남가좌동 술찾사',
#  '서대문구 창천동 소도적',
#  '서대문구 대현동 돈노코돈먹기',
#  '서대문구 홍제동 동네고기',
#  '서대문구 홍제동 모퉁이',
#  '서대문구 합동 뚱이네 숯불갈비',
#  '서대문구 남가좌동 청춘보쌈',
#  '서대문구 창천동 뉴욕비',
#  '서대문구 냉천동 본도시락(서대문점)',
#  '서대문구 현저동 독립문식당',
#  '서대문구 홍은동 홍식당',
#  '서대문구 충정로2가 엄마가 차려주신 맛있는 술상',
#  '서대문구 홍은동 한우본가갈비',
#  '서대문구 연희동 호천식당',
#  '서대문구 남가좌동 덕가',
#  '서대문구 영천동 석교식당',
#  '서대문구 홍제동 식껍 홍제역점',
#  '서대문구 창천동 훼드라',
#  '서대문구 홍은동 사랑채',
#  '서대문구 영천동 미스터 빠삭',
#  '서대문구 창천동 유닭스토리',
#  '서대문구 북가좌동 이가족발',
#  '서대문구 북가좌동 더 맛나 통닭',
#  '서대문구 대현동 염인돈(YEOMINDON)라멘',
#  '서대문구 홍제동 오늘의 식탁',
#  '서대문구 창천동 혼밥대장 신촌본점',
#  '서대문구 창천동 주간',
#  '서대문구 홍제동 왕십리곱창천하',
#  '서대문구 연희동 초가집',
#  '서대문구 창천동 롤링파스타(신촌점)',
#  '서대문구 영천동 기호네곱창',
#  '서대문구 대현동 한솥도시락(이대역점)',
#  '서대문구 대현동 박가네',
#  '서대문구 홍제동 밥보다 국시',
#  '서대문구 충정로2가 사조미가',
#  '서대문구 연희동 마포갈비',
#  '서대문구 신촌동 본우리반상 세브란스점',
#  '서대문구 창천동 배바위 양곱창',
#  '서대문구 창천동 동학',
#  '서대문구 충정로2가 봉봉',
#  '서대문구 남가좌동 모래내장어집',
#  '서대문구 북가좌동 접시고기',
#  '서대문구 연희동 연희동태찜',
#  '서대문구 연희동 백암',
#  '서대문구 홍제동 족삼리',
#  '서대문구 홍제동 이차돌 홍제역점',
#  '서대문구 연희동 박가네짬뽕',
#  '서대문구 창천동 더진국 신촌(중앙)점',
#  '서대문구 대현동 하루식당',
#  '서대문구 북아현동 가화반점',
#  '서대문구 합동 채쉐프',
#  '서대문구 충정로3가 원조봉순게장',
#  '서대문구 대현동 김가네',
#  '서대문구 합동 낟더쌔임',
#  '서대문구 남가좌동 돼지게티 남가좌점',
#  '서대문구 대현동 더데이지',
#  '서대문구 홍은동 99냉삼집',
#  '서대문구 대현동 한바가지',
#  '서대문구 창천동 동경집',
#  '서대문구 창천동 대명꼬기',
#  '서대문구 창천동 배떡 신촌점',
#  '서대문구 남가좌동 실비집',
#  '서대문구 창천동 민주네김밥',
#  '서대문구 홍은동 찜과 지짐이',
#  '서대문구 합동 독도게찜',
#  '서대문구 연희동 세양수산',
#  '서대문구 홍제동 섬진강',
#  '서대문구 홍은동 심야 별장',
#  '서대문구 충정로3가 바다양푼이동태탕',
#  '서대문구 연희동 부라더키친 마포서대문점',
#  '서대문구 창천동 인생이 막창이네',
#  '서대문구 홍은동 비탈길',
#  '서대문구 남가좌동 삼삼이네 남가좌점',
#  '서대문구 창천동 원조감자탕',
#  '서대문구 연희동 시도 플레이스',
#  '서대문구 남가좌동 짝태&노가리',
#  '서대문구 창천동 일백집 서울포차(신촌점)',
#  '서대문구 창천동 돈노코돈먹기',
#  '서대문구 창천동 명성양꼬치',
#  '서대문구 연희동 째보식당',
#  '서대문구 충정로3가 꼼지락',
#  '서대문구 남가좌동 성화칼국수',
#  '서대문구 신촌동 푸드엠파이어 야끼스타',
#  '서대문구 홍제동 미가',
#  '서대문구 충정로3가 장수가든',
#  '서대문구 남가좌동 흑장미',
#  '서대문구 홍제동 행복한피자',
#  '서대문구 홍제동 초원식당',
#  '서대문구 충정로3가 다래',
#  '서대문구 북아현동 촌놈숯불닭갈비북아현점',
#  '서대문구 창천동 서울치킨클럽',
#  '서대문구 연희동 주식회사 장도리홀딩스',
#  '서대문구 홍은동 도쿄총각',
#  '서대문구 남가좌동 장모님 국수랑전',
#  '서대문구 충정로3가 채움',
#  '서대문구 현저동 명보성',
#  '서대문구 북아현동 오박사 시오야끼',
#  '서대문구 천연동 안경할머니곱창',
#  '서대문구 북아현동 대박집',
#  '서대문구 창천동 공복',
#  '서대문구 홍제동 테트리스 찜닭',
#  '서대문구 창천동 육연소',
#  '서대문구 홍제동 대청마루 감자탕',
#  '서대문구 창천동 돈이면 돼지',
#  '서대문구 대현동 카페문(Caffe Moon)',
#  '서대문구 창천동 미도매운향솥',
#  '서대문구 홍제동 청솔식당',
#  '서대문구 홍제동 된장남',
#  '서대문구 홍은동 밥',
#  '서대문구 북아현동 큰맘할매 순대국',
#  '서대문구 홍제동 육회왕자 연어공주 홍제역점',
#  '서대문구 대현동 참참참분식',
#  '서대문구 홍제동 대박노가리',
#  '서대문구 창천동 TX홀덤',
#  '서대문구 대신동 본죽',
#  '서대문구 북가좌동 우리동네(생고기무한리필)',
#  '서대문구 북아현동 삼호곱창숯불갈비',
#  '서대문구 냉천동 피엠푸드 냉천점',
#  '서대문구 창천동 정통집(신촌점)',
#  '서대문구 홍제동 도도 포차',
#  '서대문구 북가좌동 사랑애포차',
#  '서대문구 북가좌동 송림식당',
#  '서대문구 홍제동 명성족발',
#  '서대문구 대현동 우리집식당',
#  '서대문구 영천동 최가상회 직영1호점',
#  '서대문구 남가좌동 손가네빈대떡',
#  '서대문구 남가좌동 짚신매운갈비찜 남가좌DMC점',
#  '서대문구 홍제동 누구나',
#  '서대문구 홍은동 인순이네 집밥',
#  '서대문구 홍은동 구공탄 별관',
#  '서대문구 남가좌동 따띠삼겹 명지대점',
#  '서대문구 홍은동 비비큐 명지대점',
#  '서대문구 창천동 포차천국 신촌점',
#  '서대문구 창천동 향꽃',
#  '서대문구 옥천동 숲속친구들',
#  '서대문구 신촌동 푸드엠파이어 부자밥',
#  '서대문구 대현동 한우곱창 한식뷔페',
#  '서대문구 홍제동 홍제닭한마리',
#  '서대문구 남가좌동 김가네 돼지국밥',
#  '서대문구 창천동 미슐네바베큐하우스',
#  '서대문구 북아현동 아현간장새우장',
#  '서대문구 천연동 반하는 보쌈앤밥상',
#  '서대문구 신촌동 푸드엠파이어 호탕',
#  '서대문구 창천동 대패가1900 서대문구점',
#  '서대문구 충정로3가 가마솥',
#  '서대문구 냉천동 표현식당',
#  '서대문구 남가좌동 돈까스전문점하늘정원',
#  '서대문구 홍은동 느티나무',
#  '서대문구 창천동 곱창이야기',
#  '서대문구 창천동 시골농장',
#  '서대문구 창천동 소문난집',
#  '서대문구 냉천동 남도정가',
#  '서대문구 연희동 한우명가',
#  '서대문구 홍은동 엄마손만두',
#  '서대문구 남가좌동 돼지주막',
#  '서대문구 창천동 동학물갈비',
#  '서대문구 현저동 유앤아이(You&I)',
#  '서대문구 홍은동 현대차고지 구내식당',
#  '서대문구 영천동 돼지마을',
#  '서대문구 충정로3가 하희씨부엌',
#  '서대문구 홍제동 건강나누리닭한마리전문점',
#  '서대문구 홍은동 생고기 전문점',
#  '서대문구 북가좌동 안동명가',
#  '서대문구 창천동 돈부리(신촌점)',
#  '서대문구 홍은동 동궁찜닭 홍은점',
#  '서대문구 창천동 청담동포장마차콩나물국밥',
#  '서대문구 북가좌동 달구',
#  '서대문구 남가좌동 영천식당',
#  '서대문구 홍은동 한돈의 달인 홍제점',
#  '서대문구 창천동 신촌돈부리모노',
#  '서대문구 남가좌동 원할머니보쌈족발 가재울배달점',
#  '서대문구 홍은동 느티나무',
#  '서대문구 홍은동 아벡데프리츠 명지대점',
#  '서대문구 대신동 쉼표',
#  '서대문구 창천동 베이직프라이드치킨',
#  '서대문구 충정로3가 서대문꼼장어',
#  '서대문구 창천동 삼육구(369)',
#  '서대문구 홍은동 신동철',
#  '서대문구 미근동 제주 하루돈 농장',
#  '서대문구 충정로3가 차이로드',
#  '서대문구 대현동 네네치킨&봉구스밥버거 이대역점',
#  '서대문구 홍은동 신미락',
#  '서대문구 홍은동 마포나루터',
#  '서대문구 홍제동 인왕골',
#  '서대문구 천연동 감나무집',
#  '서대문구 북가좌동 돼파 북가좌점',
#  '서대문구 홍제동 마왕족발 홍제점',
#  '서대문구 남가좌동 동남집',
#  '서대문구 신촌동 백양로플라자점',
#  '서대문구 홍은동 원조남경보리밥',
#  '서대문구 미근동 미근동 105-1',
#  '서대문구 냉천동 어 ! 국수',
#  '서대문구 홍은동 장어세상',
#  '서대문구 충정로2가 참맛집',
#  '서대문구 연희동 연희보리밥',
#  '서대문구 창천동 야곱의축복 신촌점',
#  '서대문구 남가좌동 해송황금장어',
#  '서대문구 미근동 서대문족발',
#  '서대문구 창천동 맘맘테이블(mammam table)',
#  '서대문구 창천동 비긴어게인',
#  '서대문구 북가좌동 해피포차',
#  '서대문구 미근동 장호왕곱창(본점)',
#  '서대문구 홍제동 문화유부',
#  '서대문구 충정로2가 청춘(구탁사발)',
#  '서대문구 연희동 수돈재 감자탕',
#  '서대문구 홍제동 골목식당',
#  '서대문구 연희동 걸리부',
#  '서대문구 연희동 보라네',
#  '서대문구 홍은동 원조이모네곱창',
#  '서대문구 충정로3가 공감',
#  '서대문구 창천동 쟁반집 8292',
#  '서대문구 북가좌동 홍주식당',
#  '서대문구 창천동 돈불',
#  '서대문구 홍은동 부산자갈치 꼼장어',
#  '서대문구 대현동 마 깐',
#  '서대문구 연희동 아파트',
#  '서대문구 남가좌동 청수보쌈',
#  '서대문구 홍제동 홍제동 이가면옥',
#  '서대문구 창천동 풍국면 현대백화점 신촌점',
#  '서대문구 홍제동 프렌즈 치킨',
#  '서대문구 남가좌동 왕돈까스 왕냉면',
#  '서대문구 창천동 봉구비어(신촌명물거리점) 2호점',
#  '서대문구 창천동 영웅갈비찜별사랑불고기신촌점',
#  '서대문구 연희동 궁 개성만두',
#  '서대문구 북가좌동 별미숯불갈비전문점',
#  '서대문구 북가좌동 만송골갈비탕',
#  '서대문구 창천동 꽁술',
#  '서대문구 홍제동 홍제왕십리쌍둥이곱창',
#  '서대문구 홍은동 깐부치킨',
#  '서대문구 홍은동 황소식당',
#  '서대문구 남가좌동 들향기가',
#  '서대문구 충정로2가 오동술 서대문점',
#  '서대문구 창천동 코모도',
#  '서대문구 창천동 60년전통신촌황소곱창',
#  '서대문구 북가좌동 가재울 사골 순대국',
#  '서대문구 홍제동 목포세발낙지',
#  '서대문구 홍은동 홍일품 숯불갈비?간장게장',
#  '서대문구 창천동 김덕후의 곱창조 신촌점',
#  '서대문구 홍은동 심취하다',
#  '서대문구 창천동 고기랑',
#  '서대문구 충정로2가 더 돈카츠',
#  '서대문구 홍은동 풍년갈비',
#  '서대문구 홍제동 우성식음료',
#  '서대문구 북가좌동 화로갈비',
#  '서대문구 홍제동 똥 돼지 마을',
#  '서대문구 창천동 신촌오리',
#  '서대문구 북가좌동 홍어에 미치다',
#  '서대문구 연희동 한우명가',
#  '서대문구 미근동 삼대맛집 명인멸치칼국수',
#  '서대문구 창천동 따봉이네',
#  '서대문구 연희동 스너그(Snugg)',
#  '서대문구 창천동 이가네설렁탕',
#  '서대문구 홍은동 춘향골',
#  '서대문구 홍제동 원마산아구찜 홍제점',
#  '서대문구 홍제동 맛집 함가네',
#  '서대문구 북가좌동 국선생',
#  '서대문구 창천동 브라더한정식 도시락 신촌점',
#  '서대문구 홍제동 진미정',
#  '서대문구 홍제동 원조명동찌개마을',
#  '서대문구 연희동 연희옥 연희본점',
#  '서대문구 천연동 니하오객잔',
#  '서대문구 연희동 연희일품향',
#  '서대문구 대현동 신신 브런치 지엔빙',
#  '서대문구 충정로2가 자담치킨 서대문역점',
#  '서대문구 홍은동 진차이나',
#  '서대문구 창천동 시오램(sio lamb)',
#  '서대문구 연희동 양밍산',
#  '서대문구 연희동 일화성',
#  '서대문구 대현동 천진분식 이대점',
#  '서대문구 창천동 마라하오 신촌점',
#  '서대문구 대현동 미혜식당',
#  '서대문구 북가좌동 짜장나라짬뽕나라',
#  '서대문구 북아현동 영화반점',
#  '서대문구 충정로3가 세양원',
#  '서대문구 남가좌동 동평원',
#  '서대문구 북가좌동 쿡 차이나',
#  '서대문구 남가좌동 러시안별관',
#  '서대문구 북가좌동 고기각',
#  '서대문구 홍은동 다복향마라탕',
#  '서대문구 연희동 성호각',
#  '서대문구 창천동 주식회사 백년당',
#  '서대문구 북아현동 행운각',
#  '서대문구 북가좌동 5959양꼬치',
#  '서대문구 남가좌동 대흥각',
#  '서대문구 남가좌동 산동만두',
#  '서대문구 홍은동 홍은양꼬치',
#  '서대문구 홍은동 수해복 마라탕',
#  '서대문구 남가좌동 페이안컴퍼니',
#  '서대문구 홍은동 양자강',
#  '서대문구 창천동 난향',
#  '서대문구 홍제동 홍제동잔치집',
#  '서대문구 대현동 육쌈냉면',
#  '서대문구 북아현동 초밥사랑',
#  '서대문구 남가좌동 연희김밥',
#  '서대문구 연희동 김밥천국 연희점',
#  '서대문구 냉천동 김밥천국',
#  '서대문구 홍제동 더 치킨맨',
#  '서대문구 홍제동 야미가',
#  '서대문구 대현동 이대종합분식',
#  '서대문구 창천동 배달돼지 소태식품',
#  '서대문구 홍은동 민셰프 도시락',
#  '서대문구 홍은동 청년김밥&떡볶이']

# %%
res_table['검색명'] = search_res

# %%
base_url='https://map.naver.com/v5/?c=14127676.3957465,4523397.9832608,15,0,0,0,dh'

# %%
driver = webdriver.Chrome('./driver/chromedriver')
driver.get(base_url)
time.sleep(2)
# Out:
# <ipython-input-17-7675f9c9ae4b>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./driver/chromedriver')

# %%
url_list = []

for res in tqdm_notebook(res_table['검색명']) :
    try :
        search_xpath = '/html/body/app/layout/div[3]/div[2]/shrinkable-layout/div/app-base/search-input-box/div/div[1]/div/input'
        element = driver.find_element(By.XPATH, search_xpath)
        time.sleep(0.5)
        element.clear()
        element.send_keys(res)
        element.send_keys("\n")
        time.sleep(3)
        
        url = driver.current_url
        if(url.split('/').__contains__('place')) :
            u = url.split('/')[-1].split('?')[0]
            url_list.append(u)
        else :
            driver.switch_to.frame('searchIframe')
            time.sleep(1)
            
            target_xpath = '/html/body/div[3]/div/div/div[1]/ul/li[1]/div[2]/a[1]/div/div/span[1]'
            config = driver.find_elements(By.XPATH, target_xpath)
            if len(config) == 0 :
                target_xpath = '/html/body/div[3]/div/div/div[1]/ul/li[1]/div[1]/a[1]/div/div/span[1]'
            else :
                target_xpath = '/html/body/div[3]/div/div/div[1]/ul/li[1]/div[2]/a[1]/div/div/span[1]'
                
            element = driver.find_element(By.XPATH, target_xpath)
            element.click()
            time.sleep(2)

            url = driver.current_url
            u = url.split('/')[-1].split('?')[0]
            url_list.append(u)
            time.sleep(1)

            driver.switch_to.default_content()
            time.sleep(1)
                
    except :
        print('error',res)
        url_list.append('-')
        driver.switch_to.default_content()
        time.sleep(1)

driver.close()
# Out:
# <ipython-input-18-a00b8521da7a>:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for res in tqdm_notebook(res_table['검색명']) :
# HBox(children=(FloatProgress(value=0.0, max=342.0), HTML(value='')))
# error 서대문구 창천동 떳다껍데기2
# error 서대문구 홍은동 참숯돼지천국
# error 서대문구 창천동 복성 청요릿집 신촌점
# error 서대문구 창천동 총각들의잔치 반찬하우스
# error 서대문구 충정로2가 알리오 올리오 스파케티전문점
# error 서대문구 홍은동 산천마루 누룽지백숙 삼계탕 간장게장
# error 서대문구 연희동 육정성
# error 서대문구 북가좌동 이가족발
# error 서대문구 대현동 염인돈(YEOMINDON)라멘
# error 서대문구 창천동 더진국 신촌(중앙)점
# error 서대문구 대현동 더데이지
# error 서대문구 남가좌동 실비집
# error 서대문구 합동 독도게찜
# error 서대문구 연희동 부라더키친 마포서대문점
# error 서대문구 신촌동 푸드엠파이어 야끼스타
# error 서대문구 충정로3가 장수가든
# error 서대문구 홍제동 행복한피자
# error 서대문구 홍제동 초원식당
# error 서대문구 연희동 주식회사 장도리홀딩스
# error 서대문구 현저동 명보성
# error 서대문구 북아현동 오박사 시오야끼
# error 서대문구 북가좌동 사랑애포차
# error 서대문구 영천동 최가상회 직영1호점
# error 서대문구 홍은동 구공탄 별관
# error 서대문구 옥천동 숲속친구들
# error 서대문구 신촌동 푸드엠파이어 부자밥
# error 서대문구 대현동 한우곱창 한식뷔페
# error 서대문구 창천동 미슐네바베큐하우스
# error 서대문구 북아현동 아현간장새우장
# error 서대문구 신촌동 푸드엠파이어 호탕
# error 서대문구 창천동 대패가1900 서대문구점
# error 서대문구 홍은동 현대차고지 구내식당
# error 서대문구 홍제동 건강나누리닭한마리전문점
# error 서대문구 홍은동 동궁찜닭 홍은점
# error 서대문구 창천동 청담동포장마차콩나물국밥
# error 서대문구 홍은동 아벡데프리츠 명지대점
# error 서대문구 창천동 삼육구(369)
# error 서대문구 홍은동 신동철
# error 서대문구 대현동 네네치킨&봉구스밥버거 이대역점
# error 서대문구 홍은동 신미락
# error 서대문구 북가좌동 돼파 북가좌점
# error 서대문구 홍은동 원조남경보리밥
# error 서대문구 남가좌동 해송황금장어
# error 서대문구 창천동 맘맘테이블(mammam table)
# error 서대문구 충정로2가 청춘(구탁사발)
# error 서대문구 홍제동 골목식당
# error 서대문구 대현동 마 깐
# error 서대문구 남가좌동 청수보쌈
# error 서대문구 창천동 봉구비어(신촌명물거리점) 2호점
# error 서대문구 창천동 영웅갈비찜별사랑불고기신촌점
# error 서대문구 북가좌동 별미숯불갈비전문점
# error 서대문구 충정로2가 오동술 서대문점
# error 서대문구 홍제동 우성식음료
# error 서대문구 북가좌동 홍어에 미치다
# error 서대문구 연희동 스너그(Snugg)
# error 서대문구 홍제동 맛집 함가네
# error 서대문구 홍제동 진미정
# error 서대문구 홍제동 원조명동찌개마을
# error 서대문구 연희동 연희옥 연희본점
# error 서대문구 천연동 니하오객잔
# error 서대문구 대현동 신신 브런치 지엔빙
# error 서대문구 창천동 시오램(sio lamb)
# error 서대문구 대현동 천진분식 이대점
# error 서대문구 대현동 미혜식당
# error 서대문구 남가좌동 러시안별관
# error 서대문구 창천동 주식회사 백년당
# error 서대문구 북아현동 행운각
# error 서대문구 홍은동 양자강
# error 서대문구 창천동 배달돼지 소태식품

# %%
print(len(url_list))
url_list.count('-')
# Out:
# 342
# 69

# %%
res_table['업소URL'] = url_list

# %%
res_table.to_csv('./datas/서대문구 표본(업소URL추가).csv', encoding='CP949' )
