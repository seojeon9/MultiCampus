# %% [markdown]
# ### 네이버 뉴스 섹션별 TOPIC 크롤링
# **정치, 경제, 사회, 생활/문화, IT/과학, 세계**

# %%
from urllib.request import urlopen
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
# 02_0에서 저장한 섹션별 link 파일 불러오기
#
df_menu = pd.read_csv('./crawl_data/naver_news_section.csv', index_col = 0)
df_menu.head()
# Out:
#   section                                               link
# 0    언론사별                https://news.naver.com/?viewType=pc
# 1      정치  https://news.naver.com/main/main.naver?mode=LS...
# 2      경제  https://news.naver.com/main/main.naver?mode=LS...
# 3      사회  https://news.naver.com/main/main.naver?mode=LS...
# 4   생활/문화  https://news.naver.com/main/main.naver?mode=LS...

# %% [markdown]
# **경제 섹션을 예시 코드로 작성**

# %%
df_menu['link'][2]
# Out:
# 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=101'

# %%
# 경제 섹션 소스 요청
url = df_menu['link'][2]
res = requests.get(url) # 요청 후 응답객체 반환
# ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# 원격 봇이라고 생각하고 연결 종료
# res

# urlopen() 함수는 진행됨
# res = urlopen(url)
# res.read()
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in getresponse(self)
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in begin(self)
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _read_status(self)
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#
# C:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# C:\ProgramData\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# C:\ProgramData\Anaconda3\lib\ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# ConnectionResetError: [WinError 10054] 현재 연결은 원격 호스트에 의해 강제로 끊겼습니다
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     723
# --> 724             retries = retries.increment(
#     725                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     402             if read is False or not self._is_method_retryable(method):
# --> 403                 raise six.reraise(type(error), error, _stacktrace)
#     404             elif read is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in getresponse(self)
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in begin(self)
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _read_status(self)
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#
# C:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# C:\ProgramData\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# C:\ProgramData\Anaconda3\lib\ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-7-f09aa2313d09> in <module>
#       1 # 경제 섹션 소스 요청
#       2 url = df_menu['link'][2]
# ----> 3 res = requests.get(url) # 요청 후 응답객체 반환
#       4 res
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))

# %% [markdown]
# - 위 코드처럼 자동화 봇으로 보고 연결 끊는 경우 해결방법
#     - 서버에 요청시 header를 구성해 추가해 줌. 즉, bot이 아님을 증명
#     - header 확인
#         - 브라우저에서 해당 사이트 접속 시 생성하는 헤더를
#         - 개발자 도구로 확인(브라우저 정보 : User-Agent)

# %%
# 소스 가져오기
url = df_menu['link'][2]
headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.5005.141 Whale/3.15.136.29 Safari/537.36"}
res = requests.get(url,headers=headers)

# %%
html = res.text

# %%
bs_obj = BeautifulSoup(html,'html.parser')

# %%
bs_obj
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh">
# <meta content="width=1106" name="viewport">
# <meta content="경제 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" property="og:image">
# <meta content="증권, 금융, 부동산, 기업, 국제 등 경제 분야 뉴스 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author">
# <meta content="summary" name="twitter:card"/>
# <meta content="경제 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" name="twitter:image"/>
# <meta content="증권, 금융, 부동산, 기업, 국제 등 경제 분야 뉴스 제공" name="twitter:description"/>
# <title>경제 홈 : 네이버 뉴스	</title>
# <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20220616_145844/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20220616_145844/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20220616_145844/js/news.jindo.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20220616_145844/js/news.jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='shm';
# var _MAIN_NEWS_SECTION_ID='103';
# var ccsrv='cc.naver.com';
# var g_ssc='news.sec';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Tue Jul 26 16:03:27 KST 2022";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20220616_145844/js/news.service.js" type="text/javascript"></script>
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
# </meta></meta></meta></meta></head>
# <body>
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> </a></li>
# <li class="on"><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/main/opinion/home.naver"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>07</strong>.<strong>26</strong><span class="day">(화)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h3"><a class="nclicks(lmn_eco.home)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101">경제</a></h2>
# <ul class="nav">
# <li><a class="snb_s20 nclicks(lmn_eco.mnl,,1)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=259">금융 </a></li>
# <li><a class="snb_s25 nclicks(lmn_eco.mnl,,2)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=258">증권 </a></li>
# <li><a class="snb_s119 nclicks(lmn_eco.mnl,,3)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=261">산업/재계 </a></li>
# <li><a class="snb_s21 nclicks(lmn_eco.mnl,,4)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=771">중기/벤처 </a></li>
# <li><a class="snb_s22 nclicks(lmn_eco.mnl,,5)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=260">부동산 </a></li>
# <li><a class="snb_s23 nclicks(lmn_eco.mnl,,6)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=262">글로벌 경제 </a></li>
# <li><a class="snb_s24 nclicks(lmn_eco.mnl,,7)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=310">생활경제 </a></li>
# <li><a class="snb_s19 nclicks(lmn_eco.mnl,,8)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=263">경제 일반 </a></li>
# </ul>
# <div class="snb_banner">
# <a class="nclicks(lmn_eco.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>
# </div>
# <div class="snb_banner">
# <a class="nclicks(lmn_eco.pmb,,1)" href="https://media.naver.com/channel/setting?back=main"><img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/></a>
# </div>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_body section_index">
# <div class="cluster">
# <div class="cluster_title">
# <span class="cluster_title_inner"><a class="cluster_title_icon_link _news_cluster_layer_btn" href="#biF7L"><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a></span>
# <div class="cluster_title_layer _news_cluster_layer is_hidden">
# <div class="cluster_title_layer_text">
#                             헤드라인 뉴스와 각 기사묶음 타이틀은 <br/> 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.
#                         </div>
# <div class="cluster_title_layer_image"></div>
# <button class="cluster_title_layer_close _news_cluster_layer_close_btn" type="button">닫기</button>
# </div>
# </div>
# </div>
# <div class="_persist">
# <div class="cluster">
# <div class="cluster_group _cluster_content">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207251920_00000011&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=001&amp;aid=0013334327"><span class="cluster_head_more_icon_num">15</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207251920_00000011&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=001&amp;aid=0013334327">
# <span class="cluster_head_sub_topic">인텔 파운드리 </span><span class="cluster_head_sub_topic">미디어텍 반도체 위탁생산 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/001/0013334327?sid=101">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2022/07/26/13334327.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/001/0013334327?sid=101">인텔, 대만 미디어텍 제품 생산…"파운드리 재진출 불신 불식"</a>
# <div class="cluster_text_lede">인텔이 퀄컴과 아마존에 이어 세계적인 반도체 설계업체인 대만의 미디어텍과 반도체 위탁생산(파운드리) 계약을 맺었다고 25일(현지시간) 발표했다. 로이터통 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013334327',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004080151',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/011/0004080151?sid=101">인텔 파운드리, 미디어텍 칩 생산…퀄컴·아마존 등 대형 고객사 확보 사활</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news031,0000687781',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">아이뉴스24</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/031/0000687781?sid=101">인텔, 대만 미디어텍 칩 생산…파운드리 고객사 확대</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news015,0004729005',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한국경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/015/0004729005?sid=101">"고객사 없어" 삼성이 무시했는데…인텔 깜짝 발표에 '술렁' [박신영의 일렉트로맨]</a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207261110_00000010&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=032&amp;aid=0003162402"><span class="cluster_head_more_icon_num">17</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207261110_00000010&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=032&amp;aid=0003162402">
# <span class="cluster_head_sub_topic">페이퍼컴퍼니 단속 뜨자 </span><span class="cluster_head_sub_topic">공공공사 입찰업체 절반으로 뚝 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/032/0003162402?sid=101">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/032/2022/07/26/3162402.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/032/0003162402?sid=101">‘페이퍼컴퍼니’ 세워 입찰 참여한 건설사업자 다수 적발</a>
# <div class="cluster_text_lede">‘페이퍼컴퍼니’를 세워 공공기관 발주 공사에 입찰하던 부적격 건설사업자들이 적발됐다. 정부가 단속에 나선 결과 입찰 참여 업체가 50% 이상 감소하는 등 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news032,0003162402',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">경향신문</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001211502',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBC</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/214/0001211502?sid=101">'페이퍼컴퍼니' 단속 뜨자‥공공공사 입찰업체 절반으로 '뚝'</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004775291',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니투데이</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/008/0004775291?sid=101">기술인력이 타법인 임원 겸직…공사 66건 단속 '5개 업체' 부적격</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news277,0005123367',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">아시아경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/277/0005123367?sid=101">국토부, 산하기관 발주 공사에 '부적격업체 5곳' 적발</a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207261450_00000005&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=015&amp;aid=0004729178"><span class="cluster_head_more_icon_num">19</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207261450_00000005&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=015&amp;aid=0004729178">
# <span class="cluster_head_sub_topic">경영진 책임 통감 </span><span class="cluster_head_sub_topic">박두선 대우조선 사장 사퇴 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/015/0004729178?sid=101">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/015/2022/07/26/4729178.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/015/0004729178?sid=101">대우조선, 파업 사태 대국민 사과…"분골쇄신 각오로 극복"</a>
# <div class="cluster_text_lede">대우조선해양 경영진이 금속노조 거제·통영·고성 조선하청지회의 파업으로 인한 생산 중단 등 일련의 사태에 대해 대국민 사과문을 발표했다. 경영진은 26일  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news015,0004729178',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한국경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news009,0004996156',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">매일경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/009/0004996156?sid=101">與 권성동, 대우조선에 '文정권 알박기' 책임론</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013335458',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/001/0013335458?sid=101">대우조선 경영진 "책임 통감…위기 극복하고 거취 포함 책임질 것"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news022,0003718651',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">세계일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/022/0003718651?sid=101">권성동 “文 정부, 대우조선 ‘알박기 인사’… 경영진 물러나야”</a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207261020_00000004&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=018&amp;aid=0005277241"><span class="cluster_head_more_icon_num">51</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207261020_00000004&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=018&amp;aid=0005277241">
# <span class="cluster_head_sub_topic">금싸라기 땅 용산정비창 부지 </span><span class="cluster_head_sub_topic">"용적률 1500% 이상" </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/018/0005277241?sid=101">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/018/2022/07/26/5277241.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/018/0005277241?sid=101">오세훈 "용산정비창 내 주택 6000호 공급"[일문일답]</a>
# <div class="cluster_text_lede">오세훈 서울시장은 26일 오전 서울시청에서 열린 기자설명회에서 용산 정비창 개발계획을 밝히며 “미래도시 키워드를 담아 글로벌 도시 경쟁력과 기술 혁신을  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news018,0005277241',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">이데일리</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/021/0002523745?sid=101">‘10년 방치’ 용산정비창에 ‘亞 실리콘밸리’ 세운다</a>
# <div class="cluster_text_lede">서울시, 국제업무지구 재추진 ‘입지규제 최소구역’ 최초 지정 서울 한복판의 마지막 남은 ‘금싸라기 땅’으로 불리는 용산정비창 부지 개발이 10년 만에 재추진된다. 서울시 최초로 ‘입지규제최소구역’을 지정해  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news021,0002523745',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">문화일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207260810_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=421&amp;aid=0006239839"><span class="cluster_head_more_icon_num">30</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207260810_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=421&amp;aid=0006239839">
# <span class="cluster_head_sub_topic">中 화유코발트와 "배터리 리사이클" 합작법인 만든다 </span><span class="cluster_head_sub_topic">LG엔솔 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/421/0006239839?sid=101">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2022/07/26/6239839.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/421/0006239839?sid=101">LG엔솔-中화유코발트, '배터리 리사이클' 합작법인 만든다</a>
# <div class="cluster_text_lede">LG에너지솔루션(이하 LG엔솔)이 중국 1위 코발트 정련업체와 손을 잡고 자원선순환 체계 구축에 나선다. LG엔솔은 중국 화유코발트와 배터리 리사이클 합 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006239839',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/277/0005123167?sid=101">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/277/2022/07/26/5123167.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/277/0005123167?sid=101">LG에너지솔루션, 배터리 리사이클도 합종연횡…中 화유코발트와 JV 설립</a>
# <div class="cluster_text_lede">LG에너지솔루션이 중국 1위 코발트 정련(원료에 들어 있는 금속을 뽑아내어 정제) 업체 화유코발트와 함께 배터리 재활용 시장 협업을 강화한다. LG에너지 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news277,0005123167',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">아시아경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207261000_00000003&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=025&amp;aid=0003212328"><span class="cluster_head_more_icon_num">17</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207261000_00000003&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=025&amp;aid=0003212328">
# <span class="cluster_head_sub_topic">코로나에 마약 밀수 대형화 </span><span class="cluster_head_sub_topic">상반기 전년比 11.2%↑ </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/025/0003212328?sid=101">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/025/2022/07/26/3212328.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/025/0003212328?sid=101">코로나 속 밀반입 대형화…세관에 적발된 마약, 건수↓ 중량↑</a>
# <div class="cluster_text_lede">올해 상반기 세관에 적발된 마약 밀수 건수는 1년 전보다 줄었지만, 중량은 오히려 늘었다. 코로나19 유행에 따른 항공편·출입국자 감소 속에 마약 밀반입 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003212328',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/020/0003442197?sid=101">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/020/2022/07/26/3442197.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/020/0003442197?sid=101">코로나에 마약 밀수 대형화…필로폰 적발량 1년새 2배로</a>
# <div class="cluster_text_lede">올해 상반기 국내 밀반입 마약류 적발 중량이 지난해 같은 기간에 비해 11% 늘어난 것으로 나타났다. 전년대비 건수는 줄었지만 중량은 늘어 건당 마약 밀 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news020,0003442197',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">동아일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207261520_00000002&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=001&amp;aid=0013335409"><span class="cluster_head_more_icon_num">19</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207261520_00000002&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=001&amp;aid=0013335409">
# <span class="cluster_head_sub_topic">금통위원에 신성환 홍익대 교수 </span><span class="cluster_head_sub_topic">은행연합회 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/001/0013335409?sid=101">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2022/07/26/13335409.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/001/0013335409?sid=101">신임 금통위원에 신성환 홍익대 교수…"경제 안정에 최선"</a>
# <div class="cluster_text_lede">은행연합회, 신성환 교수 추천…"20년 이상 연구한 금융전문가" 윤석열 대통령 인수위 경제1분과 인수위원 지내 한국은행 금융통화위원회 새 금융통화위원으로 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013335409',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/421/0006241445?sid=101">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2022/07/26/6241445.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/421/0006241445?sid=101">은행연합회, 한은 금통위원에 신성환 홍익대 교수 추천</a>
# <div class="cluster_text_lede">은행연합회는 지난 5월 이후 공석이었던 한국은행 금융통화위원회 위원에 신성환(59) 홍익대학교 경영학부 교수를 추천했다. 은행연합회는 26일 "한국은행법 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006241445',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207251130_00000005&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=366&amp;aid=0000830054"><span class="cluster_head_more_icon_num">33</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207251130_00000005&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=366&amp;aid=0000830054">
# <span class="cluster_head_sub_topic">상반기 석유제품 280억달러 수출 </span><span class="cluster_head_sub_topic">달러효자 정유업계 빅4 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/366/0000830054?sid=101">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/366/2022/07/26/830054.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/366/0000830054?sid=101">정유업계, 상반기 석유제품 280억달러 수출… 역대 최대</a>
# <div class="cluster_text_lede">올해 상반기 정유업계 수출액이 약 280억달러로 반기 기준 역대 최대치를 기록한 것으로 나타났다. 대한석유협회는 국내 정유 4사인 SK에너지, GS칼텍스 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000830054',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선비즈</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/016/0002020617?sid=101">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/016/2022/07/26/2020617.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/016/0002020617?sid=101">석유제품 상반기 수출 10년來 최고...반도체 이어 2위</a>
# <div class="cluster_text_lede">정유업계가 올해 상반기 반기 기준 최고 수출액을 달성하며 10년 만에 새 기록을 썼다. 국가 주요 수출품목 중 반도체 다음으로 석유제품이 2위에 올라섰다 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002020617',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">헤럴드경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207261100_00000672&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=016&amp;aid=0002020568"><span class="cluster_head_more_icon_num">35</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207261100_00000672&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=016&amp;aid=0002020568">
# <span class="cluster_head_sub_topic">금융위 금융안정계정 도입 </span><span class="cluster_head_sub_topic">부실 사전에 차단한다 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/016/0002020568?sid=101">“금융사 부실 예방...금융안정계정 도입”</a>
# <div class="cluster_text_lede">금융당국이 금융리스크에 따른 악영향을 막기 위해 각종 제도 보완 및 개선을 추진하기로 했다. 특히 금융사들의 부실예방을 위해 금융안정계정을 도입키로 했다. 금융위원회는 26일 김소영 부위원장 주재로 유관기관 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002020568',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">헤럴드경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/008/0004775368?sid=101">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/008/2022/07/26/4775368.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/008/0004775368?sid=101">김소영 부위원장 "금융사 부실 예방 위한 '금융안정계정' 도입"</a>
# <div class="cluster_text_lede">금융당국이 금융회사 부실예방을 위한 '금융안정계정' 도입을 추진한다. 부실 위험에 있는 금융사에 대한 선제 지원 개념이다. 김소영 금융위원회 부위원장은  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004775368',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니투데이</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207230500_00000003&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=003&amp;aid=0011324939"><span class="cluster_head_more_icon_num">22</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207230500_00000003&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=003&amp;aid=0011324939">
# <span class="cluster_head_sub_topic">빗썸 최대주주 비덴트 </span><span class="cluster_head_sub_topic">"FTX와 매각 검토 사실" </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/003/0011324939?sid=101">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2022/07/25/11324939.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/003/0011324939?sid=101">빗썸 관련주·삼성카드(종합)[핫스탁]</a>
# <div class="cluster_text_lede">기사내용 요약 美코인거래소 FTX, 빗썸 인수? 비덴트 상한가 삼성카드, 2Q 영업익 7% 증가에 소폭 강세 [서울=뉴◇빗썸 관련주 = 미 억만장자 샘  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011324939',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/421/0006240195?sid=101">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2022/07/26/6240195.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/421/0006240195?sid=101">韓 암호화폐 투자업체 "빗썸 매각가, 4조는 비싸다"</a>
# <div class="cluster_text_lede">해외 대형 암호화폐 거래소 FTX가 빗썸 인수를 시도한 것으로 알려지면서 빗썸 매각가에도 이목이 집중되고 있다. 일각에서 매각가가 4조원이라는 소식이 전 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006240195',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207250920_00000009&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=421&amp;aid=0006241155"><span class="cluster_head_more_icon_num">17</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207250920_00000009&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=421&amp;aid=0006241155">
# <span class="cluster_head_sub_topic">토스뱅크 1000억 유상증자 결의 </span><span class="cluster_head_sub_topic">자본금 1조500억원 확보 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/421/0006241155?sid=101">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2022/07/26/6241155.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/421/0006241155?sid=101">토스뱅크, 1000억원 규모 유상증자…총 1조500억원 자본금 확보</a>
# <div class="cluster_text_lede">토스뱅크가 전날 열린 이사회에서 1000억원 규모의 유상증자를 추진하기로 했다고 26일 밝혔다. 토스뱅크는 지난해 10월 출범 이후 네 차례의 유상증자를 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006241155',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/009/0004995938?sid=101">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/009/2022/07/25/4995938.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/009/0004995938?sid=101">토스, 주니어 개발자 공채…9개 부문에서 최대 80명</a>
# <div class="cluster_text_lede">종합 금융 플랫폼 '토스'가 경력 3년 이하 개발자를 공개 채용한다. 9개 부문에서 최대 80명을 뽑는다. 토스 운영사 비바리퍼블리카는 다음달 3일 자정 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news009,0004995938',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">매일경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207260800_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=032&amp;aid=0003162323"><span class="cluster_head_more_icon_num">23</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207260800_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=032&amp;aid=0003162323">
# <span class="cluster_head_sub_topic">서울 아파트 평균 전셋값 </span><span class="cluster_head_sub_topic">3년3개월만에 하락 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/032/0003162323?sid=101">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/032/2022/07/26/3162323.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/032/0003162323?sid=101">서울 아파트 평균 전셋값 3년 3개월 만에 하락</a>
# <div class="cluster_text_lede">서울 지역 아파트의 평균 전셋값이 3년 3개월 만에 하락한 것으로 나타났다. 전세 물건은 늘어나는데 재계약 증가, 금리 인상 등으로 전세를 찾는 수요는  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news032,0003162323',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">경향신문</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/422/0000552857?sid=101">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/422/2022/07/26/552857.jpg?type=nf132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/422/0000552857?sid=101"> 서울 아파트 평균 전셋값 하락세…집값 낙폭 커지나?[경제읽기]</a>
# <div class="cluster_text_lede">최근 서울 아파트 월세 가격이 상승하고 평균 전셋값은 하락세를 보이고 있습니다. 서민들의 주거비 부담이 우려되는 가운데 전셋값이 빠지면서 서울 아파트값  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news422,0000552857',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스TV</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="cluster _news_cluster_more_layer">
# <div class="cluster_more">
# <a class="cluster_more_inner _news_cluster_more_btn nclicks(cls_eco.clsmore)" href="#">헤드라인 더보기</a>
# </div>
# </div>
# </div>
# <div class="cluster">
# <div class="cluster_group">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_left" href="/main/hotissue/sectionList.naver?mid=hot&amp;sid1=&amp;cid=1088094">
# <div class="cluster_head_go as_series">연재보기</div>
# <h2 class="cluster_head_topic">더 머니이스트</h2>
# </a>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline" href="https://n.news.naver.com/mnews/article/015/0004728928?sid=101">현명한 '입주권 투자' 위한 단계별 절세방안[더 머니이스트-택슬리의 슬기로운 세금생활]</a>
# <div class="cluster_text_lede">사진=게티이미지뱅크「도시및주거환경정비법」상 재개발·재건축 부동산은 사업의 진행 단계에 따라 부동산의 종류가 달라집니다. 양도세·취득세·종부세 등 각종 세목에 따라 획일적이지 않고 취급이 달라 정확한 세금을  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news015,params:{sid1:'101'},0004728928',nclicks:'cmt.count'}">
# <div class="cluster_text_press">한국경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news015,0004728923',params:{sid1:'101'},nclicks:'cmt.count'}">
# <div class="cluster_text_press">한국경제</div>
# </div>
# <a class="cluster_text_headline" href="https://n.news.naver.com/mnews/article/015/0004728923?sid=101">'전력거래가격 상한제' 이대로 괜찮을까 [더 머니이스트-김태선의 탄소배출권]</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news015,0004728922',params:{sid1:'101'},nclicks:'cmt.count'}">
# <div class="cluster_text_press">한국경제</div>
# </div>
# <a class="cluster_text_headline" href="https://n.news.naver.com/mnews/article/015/0004728922?sid=101">"실수요자 내 집 마련 기회, 곧 옵니다" [더 머니이스트-최원철의 미래집]</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news015,0004728341',params:{sid1:'101'},nclicks:'cmt.count'}">
# <div class="cluster_text_press">한국경제</div>
# </div>
# <a class="cluster_text_headline" href="https://n.news.naver.com/mnews/article/015/0004728341?sid=101">종자돈 '1억' 만들고 싶다면?…'이것'부터 하세요 [더 머니이스트-김진웅의 100세 시대와 평생 자산관리]</a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="section_ad" id="glad_ad_newslist">
# <script>
#             gladsdk.cmd.push(function () {
# ...
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087474");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
# <div class="side_ad" id="glad_ad_sidebox"></div>
# <div class="section as_finance">
# <div class="as_finance_tit">
# <ul class="as_finance_tab" role="tab_list">
# <li class="on" id="tab_0"><a aria-selected="true" class="tab_stock" href="#" onclick="return false;" onkeydown="finance_tab_focus(this);" role="tab"><strong>증권</strong></a></li>
# <li id="tab_1"><a aria-selected="false" class="tab_exchange" href="#" onclick="return false;" onkeydown="finance_tab_focus(this);" role="tab">환율</a></li>
# </ul>
# <h4 class="blind">증권</h4>
# </div>
# <div id="finance_tab_0">
# <div class="as_finance_content_wrap">
# <div class="as_finance_content">
# <table cellpadding="0" cellspacing="0" class="table_finance">
# <caption class="blind">
#       코스피,코스닥 지수
#      </caption>
# <colgroup>
# <col width="66">
# <col width="76">
# <col>
# <col/>
# </col></col></col></colgroup>
# <tbody>
# <tr>
# <th scope="row"><a class="visit nclicks(rig.finance)" href="https://finance.naver.com/sise/sise_index.naver?code=KOSPI" target="_blank">코스피</a></th>
# <td class="num">2,412.96</td>
# <td class="num up"><i>상승</i>9.27</td>
# <td class="num fluctuation">+0.39%</td>
# </tr>
# <tr>
# <th scope="row"><a class="visit" href="https://finance.naver.com/sise/sise_index.naver?code=KOSDAQ" target="_blank">코스닥</a></th>
# <td class="num">789.93</td>
# <td class="num up"><i>상승</i>0.24</td>
# <td class="num fluctuation">+0.03%</td>
# </tr>
# </tbody>
# </table>
# <form action="https://finance.naver.com/search/search.naver" method="get" onsubmit="return stock_search_1079042(); return false;" target="_blank">
# <fieldset class="finance">
# <legend>증권 종목검색</legend>
# <span> <label class="blind" for="stockSearchQuery_1079042">검색어 입력</label> <input class="finance_search_input" id="stockSearchQuery_1079042" name="query" placeholder="종목검색" type="text"/> </span>
# <button class="finance_search_btn nclicks(rig.finance)">종목검색</button>
# <a class="finance_my_link nclicks(rig.finance)" href="https://finance.naver.com/mystock/" target="_blank">마이스톡</a>
# </fieldset>
# </form>
# </div>
# </div>
# <div class="as_finance_more">
# <dl class="as_finance_search_top">
# <dt>
#      검색상위
#     </dt>
# <dd>
# <a class="visit nclicks(rig.finance)" href="https://finance.naver.com/item/main.naver?code=005930" target="_blank">삼성전자</a>
# <span>|</span>
# <a class="visit nclicks(rig.finance)" href="https://finance.naver.com/item/main.naver?code=005380" target="_blank">현대차</a>
# <span>|</span>
# <a class="visit nclicks(rig.finance)" href="https://finance.naver.com/item/main.naver?code=166090" target="_blank">하나머티</a>
# </dd>
# </dl>
# </div>
# </div>
# <div id="finance_tab_1" style="display:none">
# <div class="as_finance_content_wrap">
# <div class="as_finance_content">
# <table cellpadding="0" cellspacing="0" class="table_finance_exchange">
# <caption class="blind">
#       환율정보
#      </caption>
# <colgroup>
# <col width="114"/>
# <col/>
# <col width="64"/>
# </colgroup>
# <tbody>
# <tr>
# <th scope="row"><img alt="1 USD" class="icon" height="12" src="https://imgnews.pstatic.net/image/news/2007/new_section/ico_flag_usa.gif" width="19"> 1 USD</img></th>
# <td class="num">1,309.00</td>
# <td class="num dn"><i>하락</i>-3.00</td>
# </tr>
# <tr>
# <th scope="row"><img alt="1 EUR" class="icon" height="12" src="https://imgnews.pstatic.net/image/news/2007/new_section/ico_flag_europe.gif" width="19"> 1 EUR</img></th>
# <td class="num">1,336.88</td>
# <td class="num dn"><i>하락</i>-3.07</td>
# </tr>
# <tr>
# <th scope="row"><img alt="100 JPY" class="icon" height="12" src="https://imgnews.pstatic.net/image/news/2007/new_section/ico_flag_japan.gif" width="19"> 100 JPY</img></th>
# <td class="num">957.47</td>
# <td class="num dn"><i>하락</i>-3.39</td>
# </tr>
# <tr>
# <th scope="row"><img alt="1 CNY" class="icon" height="12" src="https://imgnews.pstatic.net/image/news/2007/new_section/ico_flag_china.gif" width="19"> 1 CNY</img></th>
# <td class="num">193.69</td>
# <td class="num dn"><i>하락</i>-0.54</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="as_finance_more">
# <dl class="as_finance_time">
# <dt>
#      기준
#     </dt>
# <dd>
#      2022.07.26 15:58
#     </dd>
# </dl>
# <a class="more_link2 nclicks(rig.finance)" href="https://finance.naver.com/marketindex/exchangeMain.naver" target="_blank">환율정보 더보기</a>
# </div>
# </div>
# <script type="text/javascript">
# function stock_search_1079042() {
# var obj = jindo.$('stockSearchQuery_1079042');
# var query = obj.value.replace(/[ ]/g, "");
# obj.value = query;
# if (query == '') {
# alert("검색어를 입력해주세요.");
# return false;
# }
# }
# function fund_search_1079042() {
# var obj = jindo.$('fundSearchQuery_1079042');
# var query = obj.value.replace(/[ ]/g, "");
# obj.value = query;
# if (query == '') {
# alert("검색어를 입력해주세요.");
# return false;
# }
# }
# function finance_tab() {
# jindo.$('tab_0').onmouseover = function () {
# var pst = 0;
# for(var i=0 ; i<2; i++) {
# var liObj = jindo.$('tab_'+i);
# var AObjInliObj = liObj.querySelector('a');
# if (i == pst) {
# liObj.className = "on";
# AObjInliObj.innerHTML = "<strong>"+liObj.innerText+"</strong>";
# AObjInliObj.setAttribute('aria-selected', true);
# jindo.$('finance_tab_'+i).style.display = '';
# } else {
# liObj.className = "";
# if ( liObj.textContent != null) {
# AObjInliObj.textContent = AObjInliObj.textContent.replace("<strong>", "").replace("</strong>", "");
# }
# AObjInliObj.setAttribute('aria-selected', false);
# jindo.$('finance_tab_'+i).style.display = 'none';
# }
# }
# }
# jindo.$('tab_1').onmouseover = function () {
# var pst = 1;
# for(var i=0 ; i<2; i++) {
# var liObj = jindo.$('tab_'+i);
# var AObjInliObj = liObj.querySelector('a');
# if (i == pst) {
# liObj.className = "on";
# AObjInliObj.innerHTML = "<strong>"+liObj.innerText+"</strong>";
# AObjInliObj.setAttribute('aria-selected', true);
# jindo.$('finance_tab_'+i).style.display = '';
# } else {
# liObj.className = "";
# if ( liObj.textContent != null) {
# AObjInliObj.textContent = AObjInliObj.textContent.replace("<strong>", "").replace("</strong>", "");
# }
# AObjInliObj.setAttribute('aria-selected', false);
# jindo.$('finance_tab_'+i).style.display = 'none';
# }
# }
# }
# }
# function finance_tab_focus(el) {
# if(event.keyCode == '13') {
# jindo.$('tab_0').className = '';
# jindo.$('tab_0').querySelector('a').setAttribute('aria-selected', false);
# jindo.$('finance_tab_'+0).style.display = 'none';
# jindo.$('tab_1').className = '';
# jindo.$('tab_1').querySelector('a').setAttribute('aria-selected', false);
# jindo.$('finance_tab_'+1).style.display = 'none';
# var liObj = jindo.$(el.parentElement);
# liObj.className = 'on';
# liObj.querySelector('a').setAttribute('aria-selected', true);
# jindo.$('finance_'+liObj.id).style.display = '';
# }
# }
# function setOnOff(id) {
# var imageOn = "https://ssl.pstatic.net/static.news/image/news/admin/btn_on.gif";
# var imageOff = "https://ssl.pstatic.net/static.news/image/news/admin/btn_off.gif";
# var imageObj = jindo.$("onOffBtn_"+id);
# var imageObjSrc = imageObj.src;
# var enableValue = "";
# if (imageObjSrc.indexOf('on') > 0) {
# imageValue = imageOff;
# enableValue = "off";
# } else if (imageObjSrc.indexOf('off') > 0) {
# imageValue = imageOn;
# enableValue = "on";
# }
# Copyright.setOnOff(id, enableValue, processOnOff);
# imageObj.src = imageValue;
# }
# finance_tab();
# </script>
# </div>
# <div class="section" id="right_dailyList" style="margin-bottom:20px; white-space:nowrap;">
# <h4>분야별 주요뉴스</h4>
# <div class="classfy sd" style="display:block">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/002/0002252797?sid=100" title="대체 누구 말을 들어야 해?…북 어민 송환, 계속 말 바뀌는 尹정부와 국민의힘">대체 누구 말을 들어야 해?…북 어민 송환, 계속 말 바뀌는 尹정부와 국민의힘</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/469/0000688205?sid=100" title="윤 대통령, 한동훈 장관에 “기업 위축하는 과도한 형벌 개선하라”">윤 대통령, 한동훈 장관에 “기업 위축하는 과도한 형벌 개선하라”</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/001/0013334692?sid=100" title='"쿠데타" "국기문란"…초강경 대응에 경찰국 갈등 최고조'>"쿠데타" "국기문란"…초강경 대응에 경찰국 갈등 최고조</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011327084?sid=104" title="미얀마 반체제 인사 처형에 美정부 중국에 개입 촉구">미얀마 반체제 인사 처형에 美정부 중국에 개입 촉구</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/081/0003290123?sid=104" title="[포착] “겸허히 용서 구합니다” 인디언 모자 쓴 교황…와병 중 속죄의 순례">[포착] “겸허히 용서 구합니다” 인디언 모자 쓴 교황…와병 중 속죄의 순례</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/018/0005277317?sid=101" title='우리은행 직원, 8년간 700억원 횡령…"직인·공문 관리 부실"'>우리은행 직원, 8년간 700억원 횡령…"직인·공문 관리 부실"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/001/0013335358?sid=101" title="마천루·녹지 어우러진 한국판 '허드슨야드' 될까…용산 대변신">마천루·녹지 어우러진 한국판 '허드슨야드' 될까…용산 대변신</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/469/0000688230?sid=101" title="2분기 0.7% 불안한 성장... 하반기 소비도, 수출도 비관">2분기 0.7% 불안한 성장... 하반기 소비도, 수출도 비관</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/015/0004729132?sid=105" title="'아주매운맛' 집단행동까지…네이버노조, 파업도 MZ스럽게">'아주매운맛' 집단행동까지…네이버노조, 파업도 MZ스럽게</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/014/0004873287?sid=105" title="상반기 무선통신분쟁 KT가 가장 많았다…이통3사 5G분쟁은 2배↑">상반기 무선통신분쟁 KT가 가장 많았다…이통3사 5G분쟁은 2배↑</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/025/0003212336?sid=102" title="文때 쪼그라든 檢수사권 챙긴다…한동훈 벌써 세번째 '합수단'">文때 쪼그라든 檢수사권 챙긴다…한동훈 벌써 세번째 '합수단'</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/421/0006241338?sid=102" title="항명이냐 강압이냐…尹 대통령과 '14만 경찰' 대치 전선 고조(종합)">항명이냐 강압이냐…尹 대통령과 '14만 경찰' 대치 전선 고조(종합)</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/082/0001166697?sid=102" title='"더 잘하고 싶었다" 교무실 칩입해 악성코드 심고 시험문제 빼낸 고교생들'>"더 잘하고 싶었다" 교무실 칩입해 악성코드 심고 시험문제 빼낸 고교생들</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/022/0003719063?sid=103" title="문체부 “청와대 활용 방안 정부 내 혼선 없다… 이미 정리”">문체부 “청와대 활용 방안 정부 내 혼선 없다… 이미 정리”</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/047/0002361077?sid=103" title="&quot;이러다 고사 위험&quot; 관광객 몰리는 '우영우 팽나무' 보호 시급">"이러다 고사 위험" 관광객 몰리는 '우영우 팽나무' 보호 시급</a> </li>
# </ul>
# </ul>
# </ul>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/settings"> <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174933298_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300"> </img></a>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183229335_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"> </img></a>
# </div>
# </div>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/hotissue/sectionList.naver?mid=hot&amp;sid1=100&amp;cid=909906&amp;decorator=ombudsman&amp;confirm=true"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <hr/>
# <div class="index">
# <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.naver">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </body>
# </html>

# %% [markdown]
# - 네이버 뉴스 섹션을 확인하면 각 섹션별 topic이 있고 topic중 헤드라인이 노출
# - 섹션에서 수집하는 것 보다 토픽페이지로 이동해서 토픽기사 전체를 크롤링 하면 더 많은 기사를 추출할 수 있음
# - 섹션 페이지에서는 토픽의 타이틀과 title과 link를 크롤링
# - 단, 정치 섹션은 구성이 약간 다르므로 수정해서 사용

# %%
# 토픽 추출
# main_content > div > div._persist > div:nth-child(1) > div:nth-child(1) > div.cluster_head > div > div > h2
# h2태그의 class:cluster_head_topic
topic_list = bs_obj.findAll("h2",{"class":"cluster_head_topic"})
len(topic_list) # list로 반환
# Out:
# 13

# %%
topic_list
# Out:
# [<h2 class="cluster_head_topic">
#  <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207251920_00000011&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=001&amp;aid=0013334327">
#  <span class="cluster_head_sub_topic">인텔 파운드리 </span><span class="cluster_head_sub_topic">미디어텍 반도체 위탁생산 </span>
#  </a>
#  </h2>,
#  <h2 class="cluster_head_topic">
#  <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207261110_00000010&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=032&amp;aid=0003162402">
#  <span class="cluster_head_sub_topic">페이퍼컴퍼니 단속 뜨자 </span><span class="cluster_head_sub_topic">공공공사 입찰업체 절반으로 뚝 </span>
#  </a>
#  </h2>,
#  <h2 class="cluster_head_topic">
#  <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207261450_00000005&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=015&amp;aid=0004729178">
#  <span class="cluster_head_sub_topic">경영진 책임 통감 </span><span class="cluster_head_sub_topic">박두선 대우조선 사장 사퇴 </span>
#  </a>
#  </h2>,
#  <h2 class="cluster_head_topic">
#  <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207261020_00000004&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=018&amp;aid=0005277241">
#  <span class="cluster_head_sub_topic">금싸라기 땅 용산정비창 부지 </span><span class="cluster_head_sub_topic">"용적률 1500% 이상" </span>
#  </a>
#  </h2>,
#  <h2 class="cluster_head_topic">
#  <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207260810_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=421&amp;aid=0006239839">
#  <span class="cluster_head_sub_topic">中 화유코발트와 "배터리 리사이클" 합작법인 만든다 </span><span class="cluster_head_sub_topic">LG엔솔 </span>
#  </a>
#  </h2>,
#  <h2 class="cluster_head_topic">
#  <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207261000_00000003&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=025&amp;aid=0003212328">
#  <span class="cluster_head_sub_topic">코로나에 마약 밀수 대형화 </span><span class="cluster_head_sub_topic">상반기 전년比 11.2%↑ </span>
#  </a>
#  </h2>,
#  <h2 class="cluster_head_topic">
#  <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207261520_00000002&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=001&amp;aid=0013335409">
#  <span class="cluster_head_sub_topic">금통위원에 신성환 홍익대 교수 </span><span class="cluster_head_sub_topic">은행연합회 </span>
#  </a>
#  </h2>,
#  <h2 class="cluster_head_topic">
#  <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207251130_00000005&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=366&amp;aid=0000830054">
#  <span class="cluster_head_sub_topic">상반기 석유제품 280억달러 수출 </span><span class="cluster_head_sub_topic">달러효자 정유업계 빅4 </span>
#  </a>
#  </h2>,
#  <h2 class="cluster_head_topic">
#  <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207261100_00000672&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=016&amp;aid=0002020568">
#  <span class="cluster_head_sub_topic">금융위 금융안정계정 도입 </span><span class="cluster_head_sub_topic">부실 사전에 차단한다 </span>
#  </a>
#  </h2>,
#  <h2 class="cluster_head_topic">
#  <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207230500_00000003&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=003&amp;aid=0011324939">
#  <span class="cluster_head_sub_topic">빗썸 최대주주 비덴트 </span><span class="cluster_head_sub_topic">"FTX와 매각 검토 사실" </span>
#  </a>
#  </h2>,
#  <h2 class="cluster_head_topic">
#  <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207250920_00000009&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=421&amp;aid=0006241155">
#  <span class="cluster_head_sub_topic">토스뱅크 1000억 유상증자 결의 </span><span class="cluster_head_sub_topic">자본금 1조500억원 확보 </span>
#  </a>
#  </h2>,
#  <h2 class="cluster_head_topic">
#  <a class="nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202207260800_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=032&amp;aid=0003162323">
#  <span class="cluster_head_sub_topic">서울 아파트 평균 전셋값 </span><span class="cluster_head_sub_topic">3년3개월만에 하락 </span>
#  </a>
#  </h2>,
#  <h2 class="cluster_head_topic">더 머니이스트</h2>]

# %%
topic_list[0].find('a')
topic_list[0].find('a')['href']
topic_list[0].find('a').text.replace('\n','')
# Out:
# '인텔 파운드리 미디어텍 반도체 위탁생산 '

# %%
# 전체 토픽 title과 link 출력
for topic in topic_list :
    a_t = topic.find('a')
    print(a_t.text.replace('\n',''))
    print(a_t['href'])
# AttributeError: 'NoneType' object has no attribute 'text'
# 마지막 부분에서 a태그가 없는 요소(빈 item)가 있어서 에러 발생
# 예외처리 진행
# Out:
# 인텔 파운드리 미디어텍 반도체 위탁생산
# /main/clusterArticles.naver?id=c_202207251920_00000011&mode=LSD&mid=shm&sid1=101&oid=001&aid=0013334327
# 페이퍼컴퍼니 단속 뜨자 공공공사 입찰업체 절반으로 뚝
# /main/clusterArticles.naver?id=c_202207261110_00000010&mode=LSD&mid=shm&sid1=101&oid=032&aid=0003162402
# 경영진 책임 통감 박두선 대우조선 사장 사퇴
# /main/clusterArticles.naver?id=c_202207261450_00000005&mode=LSD&mid=shm&sid1=101&oid=015&aid=0004729178
# 금싸라기 땅 용산정비창 부지 "용적률 1500% 이상"
# /main/clusterArticles.naver?id=c_202207261020_00000004&mode=LSD&mid=shm&sid1=101&oid=018&aid=0005277241
# 中 화유코발트와 "배터리 리사이클" 합작법인 만든다 LG엔솔
# /main/clusterArticles.naver?id=c_202207260810_00000001&mode=LSD&mid=shm&sid1=101&oid=421&aid=0006239839
# 코로나에 마약 밀수 대형화 상반기 전년比 11.2%↑
# /main/clusterArticles.naver?id=c_202207261000_00000003&mode=LSD&mid=shm&sid1=101&oid=025&aid=0003212328
# 금통위원에 신성환 홍익대 교수 은행연합회
# /main/clusterArticles.naver?id=c_202207261520_00000002&mode=LSD&mid=shm&sid1=101&oid=001&aid=0013335409
# 상반기 석유제품 280억달러 수출 달러효자 정유업계 빅4
# /main/clusterArticles.naver?id=c_202207251130_00000005&mode=LSD&mid=shm&sid1=101&oid=366&aid=0000830054
# 금융위 금융안정계정 도입 부실 사전에 차단한다
# /main/clusterArticles.naver?id=c_202207261100_00000672&mode=LSD&mid=shm&sid1=101&oid=016&aid=0002020568
# 빗썸 최대주주 비덴트 "FTX와 매각 검토 사실"
# /main/clusterArticles.naver?id=c_202207230500_00000003&mode=LSD&mid=shm&sid1=101&oid=003&aid=0011324939
# 토스뱅크 1000억 유상증자 결의 자본금 1조500억원 확보
# /main/clusterArticles.naver?id=c_202207250920_00000009&mode=LSD&mid=shm&sid1=101&oid=421&aid=0006241155
# 서울 아파트 평균 전셋값 3년3개월만에 하락
# /main/clusterArticles.naver?id=c_202207260800_00000001&mode=LSD&mid=shm&sid1=101&oid=032&aid=0003162323
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-825d2ddf2325> in <module>
#       2 for topic in topic_list :
#       3     a_t = topic.find('a')
# ----> 4     print(a_t.text.replace('\n',''))
#       5     print(a_t['href'])
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
# 전체 토픽 title과 link 출력
for topic in topic_list :
    try :
        a_t = topic.find('a')
        print(a_t.text.replace('\n',''))
        print(a_t['href'])
    except :
        print("에러발생")
# AttributeError: 'NoneType' object has no attribute 'text'
# 마지막 부분에서 a태그가 없는 요소(빈 item)가 있어서 에러 발생
# 예외처리 진행
# Out:
# 인텔 파운드리 미디어텍 반도체 위탁생산
# /main/clusterArticles.naver?id=c_202207251920_00000011&mode=LSD&mid=shm&sid1=101&oid=001&aid=0013334327
# 페이퍼컴퍼니 단속 뜨자 공공공사 입찰업체 절반으로 뚝
# /main/clusterArticles.naver?id=c_202207261110_00000010&mode=LSD&mid=shm&sid1=101&oid=032&aid=0003162402
# 경영진 책임 통감 박두선 대우조선 사장 사퇴
# /main/clusterArticles.naver?id=c_202207261450_00000005&mode=LSD&mid=shm&sid1=101&oid=015&aid=0004729178
# 금싸라기 땅 용산정비창 부지 "용적률 1500% 이상"
# /main/clusterArticles.naver?id=c_202207261020_00000004&mode=LSD&mid=shm&sid1=101&oid=018&aid=0005277241
# 中 화유코발트와 "배터리 리사이클" 합작법인 만든다 LG엔솔
# /main/clusterArticles.naver?id=c_202207260810_00000001&mode=LSD&mid=shm&sid1=101&oid=421&aid=0006239839
# 코로나에 마약 밀수 대형화 상반기 전년比 11.2%↑
# /main/clusterArticles.naver?id=c_202207261000_00000003&mode=LSD&mid=shm&sid1=101&oid=025&aid=0003212328
# 금통위원에 신성환 홍익대 교수 은행연합회
# /main/clusterArticles.naver?id=c_202207261520_00000002&mode=LSD&mid=shm&sid1=101&oid=001&aid=0013335409
# 상반기 석유제품 280억달러 수출 달러효자 정유업계 빅4
# /main/clusterArticles.naver?id=c_202207251130_00000005&mode=LSD&mid=shm&sid1=101&oid=366&aid=0000830054
# 금융위 금융안정계정 도입 부실 사전에 차단한다
# /main/clusterArticles.naver?id=c_202207261100_00000672&mode=LSD&mid=shm&sid1=101&oid=016&aid=0002020568
# 빗썸 최대주주 비덴트 "FTX와 매각 검토 사실"
# /main/clusterArticles.naver?id=c_202207230500_00000003&mode=LSD&mid=shm&sid1=101&oid=003&aid=0011324939
# 토스뱅크 1000억 유상증자 결의 자본금 1조500억원 확보
# /main/clusterArticles.naver?id=c_202207250920_00000009&mode=LSD&mid=shm&sid1=101&oid=421&aid=0006241155
# 서울 아파트 평균 전셋값 3년3개월만에 하락
# /main/clusterArticles.naver?id=c_202207260800_00000001&mode=LSD&mid=shm&sid1=101&oid=032&aid=0003162323
# 에러발생

# %% [markdown]
# - base_url : https://news.naver.com
# - sub_url : /main/clusterArticles.naver?id=c_202207251130_00000383&mode=LSD&mid=shm&sid1=101&oid=648&aid=0000009369
# - 수집된 url은 기본 url이 빠져 있으므로 기본 Url을 첨부하여 수집 해야함

# %%
# link에 기본 url 추가
base_url = 'https://news.naver.com'
# 전체 토픽 title과 link 출력
for topic in topic_list :
    try :
        a_t = topic.find('a')
        print(a_t.text.replace('\n',''))
        print(base_url + a_t['href'])
    except :
        print("에러발생")
# AttributeError: 'NoneType' object has no attribute 'text'
# 마지막 부분에서 a태그가 없는 요소(빈 item)가 있어서 에러 발생
# 예외처리 진행
# Out:
# 인텔 파운드리 미디어텍 반도체 위탁생산
# https://news.naver.com/main/clusterArticles.naver?id=c_202207251920_00000011&mode=LSD&mid=shm&sid1=101&oid=001&aid=0013334327
# 페이퍼컴퍼니 단속 뜨자 공공공사 입찰업체 절반으로 뚝
# https://news.naver.com/main/clusterArticles.naver?id=c_202207261110_00000010&mode=LSD&mid=shm&sid1=101&oid=032&aid=0003162402
# 경영진 책임 통감 박두선 대우조선 사장 사퇴
# https://news.naver.com/main/clusterArticles.naver?id=c_202207261450_00000005&mode=LSD&mid=shm&sid1=101&oid=015&aid=0004729178
# 금싸라기 땅 용산정비창 부지 "용적률 1500% 이상"
# https://news.naver.com/main/clusterArticles.naver?id=c_202207261020_00000004&mode=LSD&mid=shm&sid1=101&oid=018&aid=0005277241
# 中 화유코발트와 "배터리 리사이클" 합작법인 만든다 LG엔솔
# https://news.naver.com/main/clusterArticles.naver?id=c_202207260810_00000001&mode=LSD&mid=shm&sid1=101&oid=421&aid=0006239839
# 코로나에 마약 밀수 대형화 상반기 전년比 11.2%↑
# https://news.naver.com/main/clusterArticles.naver?id=c_202207261000_00000003&mode=LSD&mid=shm&sid1=101&oid=025&aid=0003212328
# 금통위원에 신성환 홍익대 교수 은행연합회
# https://news.naver.com/main/clusterArticles.naver?id=c_202207261520_00000002&mode=LSD&mid=shm&sid1=101&oid=001&aid=0013335409
# 상반기 석유제품 280억달러 수출 달러효자 정유업계 빅4
# https://news.naver.com/main/clusterArticles.naver?id=c_202207251130_00000005&mode=LSD&mid=shm&sid1=101&oid=366&aid=0000830054
# 금융위 금융안정계정 도입 부실 사전에 차단한다
# https://news.naver.com/main/clusterArticles.naver?id=c_202207261100_00000672&mode=LSD&mid=shm&sid1=101&oid=016&aid=0002020568
# 빗썸 최대주주 비덴트 "FTX와 매각 검토 사실"
# https://news.naver.com/main/clusterArticles.naver?id=c_202207230500_00000003&mode=LSD&mid=shm&sid1=101&oid=003&aid=0011324939
# 토스뱅크 1000억 유상증자 결의 자본금 1조500억원 확보
# https://news.naver.com/main/clusterArticles.naver?id=c_202207250920_00000009&mode=LSD&mid=shm&sid1=101&oid=421&aid=0006241155
# 서울 아파트 평균 전셋값 3년3개월만에 하락
# https://news.naver.com/main/clusterArticles.naver?id=c_202207260800_00000001&mode=LSD&mid=shm&sid1=101&oid=032&aid=0003162323
# 에러발생

# %% [markdown]
# ### 수집한 data를 Dataframe으로 생성

# %%
# 수집 내용 list에 저장
topic_title=[]
topic_link=[]

# %%
# link에 기본 url 추가
base_url = 'https://news.naver.com'
# 전체 토픽 title과 link 출력
for topic in topic_list :
    try :
        a_t = topic.find('a')
        topic_title.append(a_t.text.replace('\n',''))
        topic_link.append(base_url + a_t['href'])
    except :
        print("에러발생")
# Out:
# 에러발생

# %%
topic_title
topic_link
# Out:
# ['https://news.naver.com/main/clusterArticles.naver?id=c_202207251920_00000011&mode=LSD&mid=shm&sid1=101&oid=001&aid=0013334327',
#  'https://news.naver.com/main/clusterArticles.naver?id=c_202207261110_00000010&mode=LSD&mid=shm&sid1=101&oid=032&aid=0003162402',
#  'https://news.naver.com/main/clusterArticles.naver?id=c_202207261450_00000005&mode=LSD&mid=shm&sid1=101&oid=015&aid=0004729178',
#  'https://news.naver.com/main/clusterArticles.naver?id=c_202207261020_00000004&mode=LSD&mid=shm&sid1=101&oid=018&aid=0005277241',
#  'https://news.naver.com/main/clusterArticles.naver?id=c_202207260810_00000001&mode=LSD&mid=shm&sid1=101&oid=421&aid=0006239839',
#  'https://news.naver.com/main/clusterArticles.naver?id=c_202207261000_00000003&mode=LSD&mid=shm&sid1=101&oid=025&aid=0003212328',
#  'https://news.naver.com/main/clusterArticles.naver?id=c_202207261520_00000002&mode=LSD&mid=shm&sid1=101&oid=001&aid=0013335409',
#  'https://news.naver.com/main/clusterArticles.naver?id=c_202207251130_00000005&mode=LSD&mid=shm&sid1=101&oid=366&aid=0000830054',
#  'https://news.naver.com/main/clusterArticles.naver?id=c_202207261100_00000672&mode=LSD&mid=shm&sid1=101&oid=016&aid=0002020568',
#  'https://news.naver.com/main/clusterArticles.naver?id=c_202207230500_00000003&mode=LSD&mid=shm&sid1=101&oid=003&aid=0011324939',
#  'https://news.naver.com/main/clusterArticles.naver?id=c_202207250920_00000009&mode=LSD&mid=shm&sid1=101&oid=421&aid=0006241155',
#  'https://news.naver.com/main/clusterArticles.naver?id=c_202207260800_00000001&mode=LSD&mid=shm&sid1=101&oid=032&aid=0003162323']

# %%
topic_df = pd.DataFrame({'contents':topic_title, "URL":topic_link})
topic_df.head()
# Out:
#                              contents  \
# 0              인텔 파운드리 미디어텍 반도체 위탁생산
# 1      페이퍼컴퍼니 단속 뜨자 공공공사 입찰업체 절반으로 뚝
# 2           경영진 책임 통감 박두선 대우조선 사장 사퇴
# 3     금싸라기 땅 용산정비창 부지 "용적률 1500% 이상"
# 4  中 화유코발트와 "배터리 리사이클" 합작법인 만든다 LG엔솔
#
#                                                  URL
# 0  https://news.naver.com/main/clusterArticles.na...
# 1  https://news.naver.com/main/clusterArticles.na...
# 2  https://news.naver.com/main/clusterArticles.na...
# 3  https://news.naver.com/main/clusterArticles.na...
# 4  https://news.naver.com/main/clusterArticles.na...

# %% [markdown]
# ### 위 내용을 결합해서 함수로 구성
# - 다른 섹션에도 적용하기 위해
# - 함수명 : get_topic(url)
# - 반환 : 섹션별 수집 데이터를 dict로 구성 후 반환

# %%
# 함수 구성
def get_topic(url) :
    
    # 수집 내용 list에 저장
    topic_title = []
    topic_link = []
    
    # 소스 요청해서 가져오기
    headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.5005.141 Whale/3.15.136.29 Safari/537.36"}
    res = requests.get(url,headers=headers)
    
    # 파서기 생성(bs4 객체 생성)
    html = res.text
    bs_obj = BeautifulSoup(html,'html.parser')
    
    # 토픽 추출
    # h2태그의 class:cluster_head_topic
    topic_list = bs_obj.findAll("h2",{"class":"cluster_head_topic"})
    
    # 최종 수집 항목을 list에 저장
    # link에 기본 url 추가
    base_url = 'https://news.naver.com'
    # 전체 토픽 title과 link 출력
    for topic in topic_list :
        try :
            a_t = topic.find('a')
            topic_title.append(a_t.text.replace('\n',''))
            topic_link.append(base_url + a_t['href'])
        except :
            print("에러발생")
    return({"topic":topic_title,"url":topic_link})

# %%
# 함수 테스트
get_topic(url)
# Out:
# 에러발생
# {'topic': ['금통위원에 신성환 홍익대 교수 은행연합회 ',
#   '농협금융 상반기 순익 1조3505억 최대 실적 낸 NH농협금융 ',
#   'LG엔솔 中 화유코발트와 "배터리 리사이클" 합작법인 만든다 ',
#   '금융위 금융안정계정 도입 부실 사전에 차단한다 ',
#   '"700억 횡령" 우리은행 직원 금감원 "내부통제 미흡" ',
#   '대우조선 경영진 파업 사태 대국민 사과 ',
#   '금싸라기 땅 용산정비창 부지 "용적률 1500% 이상" ',
#   '공매도 과열종목 지정 확대 과태료 8억 원 납부 ',
#   '상반기 석유제품 280억달러 수출 달러효자 정유업계 빅4 ',
#   '최태원 SK 회장 바이든 대통령 26일 화상면담 ',
#   '올해 실적 전망 낮췄다 LG전자에 1위 뺏긴 월풀 ',
#   '韓 투자환경 매력 없었다 해외직접투자 증가율 G7중 최고 '],
#  'url': ['https://news.naver.com/main/clusterArticles.naver?id=c_202207261520_00000002&mode=LSD&mid=shm&sid1=101&oid=003&aid=0011327206',
#   'https://news.naver.com/main/clusterArticles.naver?id=c_202207261340_00000001&mode=LSD&mid=shm&sid1=101&oid=366&aid=0000830068',
#   'https://news.naver.com/main/clusterArticles.naver?id=c_202207260810_00000001&mode=LSD&mid=shm&sid1=101&oid=032&aid=0003162452',
#   'https://news.naver.com/main/clusterArticles.naver?id=c_202207261100_00000672&mode=LSD&mid=shm&sid1=101&oid=277&aid=0005123438',
#   'https://news.naver.com/main/clusterArticles.naver?id=c_202207261400_00000964&mode=LSD&mid=shm&sid1=101&oid=015&aid=0004729084',
#   'https://news.naver.com/main/clusterArticles.naver?id=c_202207261450_00000005&mode=LSD&mid=shm&sid1=101&oid=025&aid=0003212386',
#   'https://news.naver.com/main/clusterArticles.naver?id=c_202207261020_00000004&mode=LSD&mid=shm&sid1=101&oid=277&aid=0005123489',
#   'https://news.naver.com/main/clusterArticles.naver?id=c_202207242350_00000725&mode=LSD&mid=shm&sid1=101&oid=277&aid=0005123349',
#   'https://news.naver.com/main/clusterArticles.naver?id=c_202207251130_00000005&mode=LSD&mid=shm&sid1=101&oid=011&aid=0004080301',
#   'https://news.naver.com/main/clusterArticles.naver?id=c_202207261120_00000044&mode=LSD&mid=shm&sid1=101&oid=421&aid=0006241394',
#   'https://news.naver.com/main/clusterArticles.naver?id=c_202207260840_00000068&mode=LSD&mid=shm&sid1=101&oid=001&aid=0013334707',
#   'https://news.naver.com/main/clusterArticles.naver?id=c_202207261210_00000006&mode=LSD&mid=shm&sid1=101&oid=025&aid=0003212381']}

# %%
# 02_0에서 저장한 섹션별 url 파일 가져오기
df_menu = pd.read_csv('./crawl_data/naver_news_section.csv', index_col=0)
df_menu.head()
# Out:
#   section                                               link
# 0    언론사별                https://news.naver.com/?viewType=pc
# 1      정치  https://news.naver.com/main/main.naver?mode=LS...
# 2      경제  https://news.naver.com/main/main.naver?mode=LS...
# 3      사회  https://news.naver.com/main/main.naver?mode=LS...
# 4   생활/문화  https://news.naver.com/main/main.naver?mode=LS...

# %%
# 함수 test
pd.DataFrame(get_topic(df_menu['link'][3]))
# Out:
# 에러발생
#                                          topic  \
# 0       "음주운전 징계" 교원 3년간 547명 무면허 30대 "징역 2년"
# 1               대기발령 후 첫 출근 "경찰국 설치가 쿠데타적 행위"
# 2                    긴급복지지원 받는 한부모 김현숙 여가부 장관
# 3                  방대본 조사 착수 "싸이 흠뻑쇼 갔다오고 확진"
# 4              류삼영 총경 경찰국 신설 졸속통과…권한쟁의심판청구 촉구
# 5                   14만 전체 경찰회의로 확대 경찰국 반발 격화
# 6              "가짜 참기름" 제조·판매업체 9곳 적발 부산시 특사경
# 7   중앙지검 2조원대 수상한 해외송금 수사 착수 신한·우리 거액 외환 이상거래
# 8            수돗물 유충 18일째 원인도 몰라 "홍남표 시장 안 보여"
# 9                   대구 30대 여교사 남고생 제자와 부적절 관계
# 10        BA.5 국내감염 검출률 49.1% 해외유입 합산하면 56.3%
# 11                 냉장고에 아버지 시신 갈비뼈 골절 "학대 정황"
# 12          "휴대용 선풍기" 전자파 환경단체 "25cm 거리두기 필요"
# 13            건설노조 인권위 진정 "172명 현장에 화장실 2.5개"
# 14            본인들 성관계 영상도 팔아 예비부부 음란물로 수억원 취득
# 15       "교사 컴퓨터에 악성코드" 심어 광주대동고 기말고사 답안 유출사건
#
#                                                   url
# 0   https://news.naver.com/main/clusterArticles.na...
# 1   https://news.naver.com/main/clusterArticles.na...
# 2   https://news.naver.com/main/clusterArticles.na...
# 3   https://news.naver.com/main/clusterArticles.na...
# 4   https://news.naver.com/main/clusterArticles.na...
# 5   https://news.naver.com/main/clusterArticles.na...
# 6   https://news.naver.com/main/clusterArticles.na...
# 7   https://news.naver.com/main/clusterArticles.na...
# 8   https://news.naver.com/main/clusterArticles.na...
# 9   https://news.naver.com/main/clusterArticles.na...
# 10  https://news.naver.com/main/clusterArticles.na...
# 11  https://news.naver.com/main/clusterArticles.na...
# 12  https://news.naver.com/main/clusterArticles.na...
# 13  https://news.naver.com/main/clusterArticles.na...
# 14  https://news.naver.com/main/clusterArticles.na...
# 15  https://news.naver.com/main/clusterArticles.na...

# %%
# 함수 구성 + section
def get_topic(url, section) :
    
    # 수집 내용 list에 저장
    topic_title = []
    topic_link = []
    
    # 소스 요청해서 가져오기
    headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.5005.141 Whale/3.15.136.29 Safari/537.36"}
    res = requests.get(url,headers=headers)
    
    # 파서기 생성(bs4 객체 생성)
    html = res.text
    bs_obj = BeautifulSoup(html,'html.parser')
    
    # 토픽 추출
    # h2태그의 class:cluster_head_topic
    topic_list = bs_obj.findAll("h2",{"class":"cluster_head_topic"})
    
    # 최종 수집 항목을 list에 저장
    # link에 기본 url 추가
    base_url = 'https://news.naver.com'
    # 전체 토픽 title과 link 출력
    for topic in topic_list :
        try :
            a_t = topic.find('a')
            topic_title.append(a_t.text.replace('\n',''))
            topic_link.append(base_url + a_t['href'])
        except :
            print("에러발생")
    return({"topic":topic_title,"url":topic_link, "section":section})

# %%
# 02_0에서 저장한 섹션별 url 파일 가져오기
df_menu = pd.read_csv('./crawl_data/naver_news_section.csv', index_col=0)
df_menu.head(8)
# Out:
#   section                                               link
# 0    언론사별                https://news.naver.com/?viewType=pc
# 1      정치  https://news.naver.com/main/main.naver?mode=LS...
# 2      경제  https://news.naver.com/main/main.naver?mode=LS...
# 3      사회  https://news.naver.com/main/main.naver?mode=LS...
# 4   생활/문화  https://news.naver.com/main/main.naver?mode=LS...
# 5   IT/과학  https://news.naver.com/main/main.naver?mode=LS...
# 6      세계  https://news.naver.com/main/main.naver?mode=LS...
# 7      랭킹  https://news.naver.com/main/ranking/popularDay...

# %%
# 함수 test
pd.DataFrame(get_topic(df_menu['link'][3],df_menu['section'][3]))
# Out:
# 에러발생
#                                          topic  \
# 0              "가짜 참기름" 제조·판매업체 9곳 적발 부산시 특사경
# 1              대형마트 규제 완화 움직임 "의무휴업 폐지" 논의 점화
# 2         BA.5 국내감염 검출률 49.1% 해외유입 합산하면 56.3%
# 3                   대구 30대 여교사 남고생 제자와 부적절 관계
# 4   중앙지검 2조원대 수상한 해외송금 수사 착수 신한·우리 거액 외환 이상거래
# 5              대구에 자율주행 분야 투자 프랑스 자동차부품기업 발레오
# 6            수돗물 유충 18일째 원인도 몰라 "홍남표 시장 안 보여"
# 7        방위사업청 이전 범시민 추진위 본격 가동 대전시 범시민추진위 발족
# 8                 킥보드 출근 40대 주정차 차량 피하려다 굴착기에
# 9           "우영우 팽나무" 현실서도 천연기념물 되나 관광객 몰려 몸살
# 10          "휴대용 선풍기" 전자파 환경단체 "25cm 거리두기 필요"
# 11            전남 관광지 방문고객 우대금리 광주은행 남도투어적금 출시
# 12             류삼영 총경 경찰국 신설 졸속통과…권한쟁의심판청구 촉구
# 13                집단 항명 공무원법 위반 서장회의 참석 총경 고발
# 14       한국인 기대수명 83.5세로 증가 외래진료 1년에 14.7번 간다
# 15                  14만 전체 경찰회의로 확대 경찰국 반발 격화
#
#                                                   url section
# 0   https://news.naver.com/main/clusterArticles.na...      사회
# 1   https://news.naver.com/main/clusterArticles.na...      사회
# 2   https://news.naver.com/main/clusterArticles.na...      사회
# 3   https://news.naver.com/main/clusterArticles.na...      사회
# 4   https://news.naver.com/main/clusterArticles.na...      사회
# 5   https://news.naver.com/main/clusterArticles.na...      사회
# 6   https://news.naver.com/main/clusterArticles.na...      사회
# 7   https://news.naver.com/main/clusterArticles.na...      사회
# 8   https://news.naver.com/main/clusterArticles.na...      사회
# 9   https://news.naver.com/main/clusterArticles.na...      사회
# 10  https://news.naver.com/main/clusterArticles.na...      사회
# 11  https://news.naver.com/main/clusterArticles.na...      사회
# 12  https://news.naver.com/main/clusterArticles.na...      사회
# 13  https://news.naver.com/main/clusterArticles.na...      사회
# 14  https://news.naver.com/main/clusterArticles.na...      사회
# 15  https://news.naver.com/main/clusterArticles.na...      사회

# %% [markdown]
# ### 추출하려하는 모든 섹션에 적용

# %%
# 모든 섹션의 topic을 하나의 dataframe에 저장하기 위해 빈 dataframe을 생성
dict_sub={}
dict_sub['topic']=[]
dict_sub['url']=[]
dict_sub['section']=[]

topic_df = pd.DataFrame(dict_sub)
topic_df
# Out:
# Empty DataFrame
# Columns: [topic, url, section]
# Index: []

# %%
# 섹션별 헤드라인 추출
for i in range(1,7) :
    temp = pd.DataFrame(get_topic(df_menu['link'][i],df_menu['section'][i]))
    topic_df = pd.concat([topic_df,temp],axis=0,ignore_index=True)
# Out:
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생

# %%
topic_df.head()
topic_df.tail()
# Out:
#                                 topic  \
# 50  "아베 경호" 실패 日 경찰 이번엔 부인 탑승 경호차 추돌
# 51        상반기 LNG 수출 1위 美 우크라전쟁 반사이익
# 52  러 "유럽행 가스관" 추가 차단 노르트스트림1 또 유지보수
# 53        폭염 속 알프스가 녹는다 역대급 빙점고도 초긴장
# 54        상대 선수 은퇴 선언 경기 중 쓰러져 결국 사망
#
#                                                   url section
# 50  https://news.naver.com/main/clusterArticles.na...      세계
# 51  https://news.naver.com/main/clusterArticles.na...      세계
# 52  https://news.naver.com/main/clusterArticles.na...      세계
# 53  https://news.naver.com/main/clusterArticles.na...      세계
# 54  https://news.naver.com/main/clusterArticles.na...      세계

# %% [markdown]
# ### 위 결과에는 정치 섹션이 들어오지 않음 - 태그 구성이 다르기 때문에
# - 정치 섹션도 포함되게 함수 변경
# - https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100 를 확인하면 topic이 따로 없음

# %%
# 함수 구성 + section
def get_topic(url, section) :
    
    # 수집 내용 list에 저장
    topic_title = []
    topic_link = []
    
    # 소스 요청해서 가져오기
    headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.5005.141 Whale/3.15.136.29 Safari/537.36"}
    res = requests.get(url,headers=headers)
    
    # 파서기 생성(bs4 객체 생성)
    html = res.text
    bs_obj = BeautifulSoup(html,'html.parser')
    
    # section이 정치인 경우는 다른 태그를 추출
    if section == '정치' :
        topic_list = bs_obj.findAll('div',{'class':'cluster_foot_inner'})
    else :
        # 토픽 추출
        # h2태그의 class:cluster_head_topic
        topic_list = bs_obj.findAll("h2",{"class":"cluster_head_topic"})
     
    # 최종 수집 항목을 list에 저장
    # link에 기본 url 추가
    base_url = 'https://news.naver.com'
    # 전체 토픽 title과 link 출력
    for topic in topic_list :
        try :
            a_t = topic.find('a')
            topic_title.append(a_t.text.replace('\n',''))
            topic_link.append(base_url + a_t['href'])
        except :
            print("에러발생")
    return({"topic":topic_title,"url":topic_link, "section":section})

# %%
# 모든 섹션의 topic을 하나의 dataframe에 저장하기 위해 빈 dataframe을 생성
dict_sub={}
dict_sub['topic']=[]
dict_sub['url']=[]
dict_sub['section']=[]

topic_df = pd.DataFrame(dict_sub)
topic_df
# Out:
# Empty DataFrame
# Columns: [topic, url, section]
# Index: []

# %%
# 섹션별 헤드라인 추출
for i in range(1,7) :
    temp = pd.DataFrame(get_topic(df_menu['link'][i],df_menu['section'][i]))
    topic_df = pd.concat([topic_df,temp],axis=0,ignore_index=True)
# Out:
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생

# %%
topic_df.head()
topic_df.tail()
# Out:
#                                 topic  \
# 66         베이징서 인니 대통령과 회담 칩거 끝낸 시진핑
# 67        러 가스 공급 감축에 EU 에너지장관 대책 논의
# 68        미얀마 정치범 사형 집행에 국제사회 규탄 이어져
# 69  러 "유럽행 가스관" 추가 차단 노르트스트림1 또 유지보수
# 70  홍콩대 졸업하려면 국가보안법 이수해야 시진핑 연설도 익혀야
#
#                                                   url section
# 66  https://news.naver.com/main/clusterArticles.na...      세계
# 67  https://news.naver.com/main/clusterArticles.na...      세계
# 68  https://news.naver.com/main/clusterArticles.na...      세계
# 69  https://news.naver.com/main/clusterArticles.na...      세계
# 70  https://news.naver.com/main/clusterArticles.na...      세계

# %%
# 파일로 저장
topic_df.to_csv('./crawl_data/naver_news_topic.csv')
