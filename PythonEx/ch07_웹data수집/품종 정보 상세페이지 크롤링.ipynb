# %%
from urllib.request import urlopen
import requests
import pandas as pd
import bs4 # 파싱패키지
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.11) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
url = 'https://terms.naver.com/entry.naver?docId=989030&cid=46677&categoryId=46677'

# %%
headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.5005.141 Whale/3.15.136.29 Safari/537.36"}
res = requests.get(url, headers=headers)

# %%
html = res.text
bs_obj = bs4.BeautifulSoup(html,'html.parser')

# %%
bs_obj
# Out:
# <!DOCTYPE html>
#
# <html data-agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.5005.141 Whale/3.15.136.29 Safari/537.36" lang="ko">
# <head>
# <link href="https://terms.naver.com/" rel="canonical"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="requiresActiveX=true;IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="article" property="og:type"/>
# <meta content="https://terms.naver.com/entry.naver?cid=46677&amp;docId=989030&amp;categoryId=46677" property="og:url"/>
# <meta content="그레이트 피레니즈" property="og:title"/>
# <meta content="https://dbscthumb-phinf.pstatic.net/3006_000_1/20140409152232460_TKB90BQ9G.jpg/DK004.jpg?type=w450_fst_n" property="og:image"/>
# ...

# %%
bs_obj.select('h2')[1].text
# Out:
# '진돗개'

# %%
profile_list = bs_obj.find('div',{'class','tmp_profile'})

# %%
profile_list
# Out:
# <div class="tmp_profile">
# <table class="tmp_profile_tb">
# <colgroup>
# <col class="tmp_col"/>
# <col width="*"/>
# </colgroup>
# <tbody>
# <tr>
# <th scope="row"><span class="title">원산지</span></th>
# <td>
#                                         프랑스
#
#                                 </td>
# </tr>
# <tr>
# <th scope="row"><span class="title">체고</span></th>
# <td>
#                                         71~76cm
#
#                                 </td>
# </tr>
# <tr>
# <th scope="row"><span class="title">체중</span></th>
# <td>
#                                         46~54kg
#
#                                 </td>
# </tr>
# <tr>
# <th scope="row"><span class="title">크기</span></th>
# <td>
#                                         초대형
#
#                                 </td>
# </tr>
# <tr>
# <th scope="row"><span class="title">외모</span></th>
# <td>
#                                         전체적으로 거대한 크기와 위풍당당함을 겸비한 견종
#
#                                 </td>
# </tr>
# <tr>
# ...

# %%
pl_td = profile_list.select('td')

# %%
pl_td[13].text.strip()
# Out:
# '실외'

# %%
#빈 DataFrame 생성
dog_kind = pd.DataFrame(columns=['원산지','체고','체중','크기','외모','성격','추천성향','주요유의질병','색상','그룹구분','친화성','털빠짐','집지키기','실내외구분'])
print(dog_kind)
# Out:
# Empty DataFrame
# Columns: [원산지, 체고, 체중, 크기, 외모, 성격, 추천성향, 주요유의질병, 색상, 그룹구분, 친화성, 털빠짐, 집지키기, 실내외구분]
# Index: []

# %%
원산지 = pl_td[0].text.strip()
체고 = pl_td[1].text.strip()
체중 = pl_td[2].text.strip()
크기 = pl_td[3].text.strip()
외모 = pl_td[4].text.strip()
성격 = pl_td[5].text.strip()
추천성향 = pl_td[6].text.replace(' ','').replace('\n','') 
주요유의질병 = pl_td[7].text.replace(' ','').replace('\n','')
색상 = pl_td[8].text.strip()
그룹구분 = pl_td[9].text.strip().split(' ')[0]
친화성 = pl_td[10].text.strip()
털빠짐 = pl_td[11].text.strip()
집지키기 = pl_td[12].text.strip()
실내외구분 = pl_td[13].text.strip()

# %%
dog_kind.loc[len(dog_kind)] = [원산지,체고,체중,크기,외모,성격,추천성향,주요유의질병,색상,그룹구분,친화성,털빠짐,집지키기,실내외구분]

# %%
dog_kind
# Out:
#    원산지       체고       체중   크기                           외모  \
# 0  프랑스  71~76cm  46~54kg  초대형  전체적으로 거대한 크기와 위풍당당함을 겸비한 견종
#
#                                    성격                 추천성향  \
# 0  고집스러우나 희생과 충성심, 보호심, 사람에 대한 사려가 깊음  단독주택/전원주택,젊은층,운동량많음
#
#                   주요유의질병                 색상 그룹구분 친화성 털빠짐 집지키기 실내외구분
# 0  관절염,지루성피부염,음식알레르기,백내장  흰색 흰색&갈색의반점 흰색&회색   워킹  보통  많음   보통    실외

# %%
url_list = ['https://terms.naver.com/entry.naver?docId=989152&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989109&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989027&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989122&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989138&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989036&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989148&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989089&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989142&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989049&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989073&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989047&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989081&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989133&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989087&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989039&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989059&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989076&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989045&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989127&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989090&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989054&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989123&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989093&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989108&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989128&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989028&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989120&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989037&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989111&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989153&cid=42883&categoryId=44358',
           'https://terms.naver.com/entry.naver?docId=989143&cid=42883&categoryId=44358',
           ]

# %%
headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.5005.141 Whale/3.15.136.29 Safari/537.36"}

#빈 DataFrame 생성
dog_kind = pd.DataFrame(columns=['품종','원산지','체고','체중','크기','외모','성격','추천성향','주요유의질병','색상','그룹구분','친화성','털빠짐','집지키기','실내외구분'])
print(dog_kind)

for url in url_list:
    res = requests.get(url, headers=headers)

    html = res.text
    bs_obj = bs4.BeautifulSoup(html,'html.parser')

    품종 = bs_obj.select('h2')[1].text

    profile_list = bs_obj.find('div',{'class','tmp_profile'})

    pl_td = profile_list.select('td')

    원산지 = pl_td[0].text.strip()
    체고 = pl_td[1].text.strip()
    체중 = pl_td[2].text.strip()
    크기 = pl_td[3].text.strip()
    외모 = pl_td[4].text.strip()
    성격 = pl_td[5].text.strip()
    추천성향 = pl_td[6].text.replace(' ','').replace('\n','') 
    
    if pl_td[7].select('a') == []:
        주요유의질병 = ''
        
        색상 = pl_td[7].text.strip()
        그룹구분 = pl_td[8].text.strip().split(' ')[0]
        친화성 = pl_td[9].text.strip()
        털빠짐 = pl_td[10].text.strip()
        집지키기 = pl_td[11].text.strip()
        실내외구분 = pl_td[12].text.strip()
        
    else :
        주요유의질병 = pl_td[7].text.replace(' ','').replace('\n','')
    
        색상 = pl_td[8].text.strip()
        그룹구분 = pl_td[9].text.strip().split(' ')[0]
        친화성 = pl_td[10].text.strip()
        털빠짐 = pl_td[11].text.strip()
        집지키기 = pl_td[12].text.strip()
        실내외구분 = pl_td[13].text.strip()

    dog_kind.loc[len(dog_kind)] = [품종,원산지,체고,체중,크기,외모,성격,추천성향,주요유의질병,색상,그룹구분,친화성,털빠짐,집지키기,실내외구분]

    
    
dog_kind
# Out:
# Empty DataFrame
# Columns: [품종, 원산지, 체고, 체중, 크기, 외모, 성격, 추천성향, 주요유의질병, 색상, 그룹구분, 친화성, 털빠짐, 집지키기, 실내외구분]
# Index: []
#                   품종                                                원산지  \
# 0             핏불 테리어                                                 미국
# 1              웰시 코기                                                 영국
# 2            골든 리트리버                                                 영국
# 3                진돗개                                                 한국
# 4              토이 푸들                                                프랑스
# 5               닥스훈트                                                 독일
# 6                풍산개                                                 한국
# 7           시베리안 허스키                                               시베리아
# 8                파피용  프랑스, \n                                       ...
# 9            미니어처 푸들                                                프랑스
# ...

# %%
from konlpy.tag import Kkma
from konlpy.utils import pprint

# %%
kkma = Kkma()
pprint(kkma.nouns(u'질문이나 건의사항은 깃헙 이슈 트래커에 남겨주세요.'))
# Out:
# ['질문', '건의', '건의사항', '사항', '깃헙', '이슈', '트래커']

# %%
# dog_kind['성격'][0]
pos_character = kkma.pos(dog_kind['성격'][0])

# %%
pos_character
# Out:
# [('느긋', 'XR'),
#  ('하', 'XSA'),
#  ('고', 'ECE'),
#  ('조용', 'XR'),
#  ('하', 'XSA'),
#  ('지만', 'ECE'),
#  ('아주', 'MAG'),
#  ('강하', 'VV'),
#  ('고', 'ECE'),
#  ('대담', 'NNG'),
#  ('하', 'XSV'),
#  ('면서', 'ECE'),
#  ('도', 'JX'),
#  ('냉철', 'XR'),
#  ('하', 'XSA'),
#  ('ㅁ', 'ETN')]

# %%
word_list = []

# %%
for pos in pos_character:
    if pos[1] in ['XR','NNG']:
        word_list.append(pos[0])

# %%
" ".join(word_list)
# Out:
# '느긋 조용 대담 냉철'

# %%
dog_kind_word_list = []

for i in range(len(dog_kind)):
    pos_character = kkma.pos(dog_kind['성격'][i])
    
    word_list = []
    
    for pos in pos_character:
        if pos[1] in ['XR','NNG']:
            word_list.append(pos[0])
    word = " ".join(word_list)
    
    dog_kind_word_list.append(word)

# %%
dog_kind_word_list
# Out:
# ['느긋 조용 대담 냉철',
#  '자신감 친절',
#  '친밀 믿음 애정 확실 성품',
#  '수렵 강 본능 대담 용감 신중 맹렬',
#  '활동적 명랑 지적 훈련 능력',
#  '명랑 장난 성질 강',
#  '주인 충성심 한번 주인 영원 주인',
#  '무뚝뚝 사람 주인 기분',
#  '활기 명랑 쾌활 소란 용기 애정',
#  '호화 털 영리 재능',
#  '독립심 세심 친밀 명랑',
#  '활달 질투 응석 사람 친밀',
#  '상냥 온화 아이',
#  '자신감 의지 독립심 강',
#  '활동적 지적 성품',
#  '원기 왕성 주의 단호 충직 순종',
#  '활력 민첩 의욕적 친구 다정',
#  '총명 충직 역동적 우호적 적응',
#  '용기 위엄 순종',
#  '기민 용감 호기심 테리어 기질 있음',
#  '사교적 친근 영리 고집 함',
#  '참을성 마음씨 사랑 천성',
#  '예리 영민 독립성 사람 경계심 강',
#  '낙천적 사람 순종 성품',
#  '용기 자신 신뢰 우호적',
#  '활발 친절 겁 모험적 유순 애정 풍부',
#  '관찰력 민첩성 끈기 강인 정',
#  '총명 용감 쾌활 가족',
#  '부끄러움 신경질 외향 성품',
#  '완고 사람 개 붙임성 깔끔 성격',
#  '상냥 우호적 사냥 때 맹렬',
#  '느긋 성질 주인 애정 다정 인내심 강']

# %%
dog_kind['성격단어'] = dog_kind_word_list

# %%
dog_kind[['품종','성격단어','친화성','털빠짐','집지키기']]
# Out:
#                   품종                  성격단어 친화성 털빠짐 집지키기
# 0             핏불 테리어           느긋 조용 대담 냉철  높음  보통   보통
# 1              웰시 코기                자신감 친절  보통  많음   보통
# 2            골든 리트리버        친밀 믿음 애정 확실 성품  높음  많음  부적절
# 3                진돗개   수렵 강 본능 대담 용감 신중 맹렬  낮음  보통  뛰어남
# 4              토이 푸들       활동적 명랑 지적 훈련 능력  높음  적음   보통
# 5               닥스훈트            명랑 장난 성질 강  보통  보통   보통
# 6                풍산개    주인 충성심 한번 주인 영원 주인  낮음  보통  뛰어남
# 7           시베리안 허스키          무뚝뚝 사람 주인 기분  보통  많음  부적절
# 8                파피용     활기 명랑 쾌활 소란 용기 애정  높음  보통  부적절
# 9            미니어처 푸들            호화 털 영리 재능  높음  적음   보통
# 10            비숑 프리제          독립심 세심 친밀 명랑  높음  적음  부적절
# 11               몰티즈        활달 질투 응석 사람 친밀  높음  보통   보통
# 12           세인트 버나드              상냥 온화 아이  보통  보통  뛰어남
# 13         코카시안 오브차카          자신감 의지 독립심 강  낮음  보통  뛰어남
# 14           스탠더드 푸들             활동적 지적 성품  보통  적음   보통
# 15           도베르만 핀셔     원기 왕성 주의 단호 충직 순종  보통  보통  뛰어남
# ...

# %%
dog_kind.to_csv('/품종별 성격.csv', encoding='CP949')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-35-5a9b73ba75c4> in <module>
# ----> 1 dog_kind.to_csv('/품종별 성격.csv', encoding='CP949')
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3549         )
#    3550
# -> 3551         return DataFrameRenderer(formatter).to_csv(
#    3552             path_or_buf,
#    3553             line_terminator=line_terminator,
#
# ...
